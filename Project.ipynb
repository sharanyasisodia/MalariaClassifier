# %% [markdown]
# <a href="https://colab.research.google.com/github/sharanyasisodia/MalariaClassifier/blob/master/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pwd
# !pip install wget
# !mkdir data
# %cd data
# !pwd
# Out:
# /content
# Collecting wget
#   Downloading https://files.pythonhosted.org/packages/47/6a/62e288da7bcda82b935ff0c6cfe542970f04e29c756b0e147251b2fb251f/wget-3.2.zip
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-cp36-none-any.whl size=9682 sha256=dbe18ddb1ef74ecacc069596e92355b0076ae39e9affda23e97478f4357b9258
#   Stored in directory: /root/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
# /content/data
# /content/data

# %%
import wget
from zipfile import ZipFile

# %%
url = "ftp://lhcftp.nlm.nih.gov/Open-Access-Datasets/Malaria/cell_images.zip"
wget.download(url, '/content/data')
# Create a ZipFile Object and load sample.zip in it
with ZipFile('cell_images.zip', 'r') as zipObj:
   # Extract all the contents of zip file in current directory
   zipObj.extractall()

# %%
import os
import glob

# %%
base_dir = os.path.join('./cell_images')
infected_dir = os.path.join(base_dir,'Parasitized')
healthy_dir = os.path.join(base_dir,'Uninfected')

infected_files = glob.glob(infected_dir+'/*.png')
healthy_files = glob.glob(healthy_dir+'/*.png')
len(infected_files), len(healthy_files)
# Out:
# (13779, 13779)

# %%
import numpy as np
import pandas as pd

np.random.seed(42)

files_df = pd.DataFrame({
    'filename': infected_files + healthy_files,
    'label': ['malaria'] * len(infected_files) + ['healthy'] * len(healthy_files)
}).sample(frac=1, random_state=42).reset_index(drop=True)

# files_df = pd.DataFrame({
#     'filename': File_name,
#     'label': Image_labels
# }).sample(frac=1, random_state=42).reset_index(drop=True)

files_df.head()
# Out:
#                                             filename    label
# 0  ./cell_images/Parasitized/C113P74ThinF_IMG_201...  malaria
# 1  ./cell_images/Parasitized/C129P90ThinF_IMG_201...  malaria
# 2  ./cell_images/Uninfected/C67P28N_ThinF_IMG_201...  healthy
# 3  ./cell_images/Uninfected/C203ThinF_IMG_2015102...  healthy
# 4  ./cell_images/Uninfected/C125P86ThinF_IMG_2015...  healthy

# %%
from sklearn.model_selection import train_test_split
from collections import Counter

train_files, test_files, train_labels, test_labels = train_test_split(files_df['filename'].values,
                                                                      files_df['label'].values,
                                                                      test_size=0.3, random_state=42)
train_files, val_files, train_labels, val_labels = train_test_split(train_files,
                                                                    train_labels,
                                                                    test_size=0.1, random_state=42)

print(train_files.shape, val_files.shape, test_files.shape)
print('Train:', Counter(train_labels), '\nVal:', Counter(val_labels), '\nTest:', Counter(test_labels))
# Out:
# (17361,) (1929,) (8268,)
# Train: Counter({'healthy': 8734, 'malaria': 8627})
# Val: Counter({'healthy': 970, 'malaria': 959})
# Test: Counter({'malaria': 4193, 'healthy': 4075})

# %%
import cv2
from concurrent import futures
import threading

def get_img_shape_parallel(idx, img, total_imgs):
    if idx % 5000 == 0 or idx == (total_imgs - 1):
        print('{}: working on img num: {}'.format(threading.current_thread().name,
                                                  idx))
    return cv2.imread(img).shape
 
ex = futures.ThreadPoolExecutor(max_workers=None)
data_inp = [(idx, img, len(train_files)) for idx, img in enumerate(train_files)]
print('Starting Img shape computation:')
# display(data_inp[0])
test = [record[1] for record in data_inp]
display(test)
train_img_dims_map = ex.map(get_img_shape_parallel,
                            [record[0] for record in data_inp],
                            [record[1] for record in data_inp],
                            [record[2] for record in data_inp])
train_img_dims = list(train_img_dims_map)
print('Min Dimensions:', np.min(train_img_dims, axis=0))
print('Avg Dimensions:', np.mean(train_img_dims, axis=0))
print('Median Dimensions:', np.median(train_img_dims, axis=0))
print('Max Dimensions:', np.max(train_img_dims, axis=0))
# display(train_img_dims)
# Out:
# Starting Img shape computation:
# ['./cell_images/Parasitized/C97P58ThinF_IMG_20150917_151437_cell_172.png',
#  './cell_images/Parasitized/C68P29N_ThinF_IMG_20150819_134625_cell_12.png',
#  './cell_images/Parasitized/C126P87ThinF_IMG_20151004_104441_cell_118.png',
#  './cell_images/Uninfected/C210ThinF_IMG_20151029_162439_cell_188.png',
#  './cell_images/Uninfected/C177P138NThinF_IMG_20151201_142514_cell_11.png',
#  './cell_images/Parasitized/C118P79ThinF_IMG_20151002_105827_cell_130.png',
#  './cell_images/Uninfected/C83P44ThinF_IMG_20150817_134820_cell_164.png',
#  './cell_images/Parasitized/C97P58ThinF_IMG_20150917_152032_cell_159.png',
#  './cell_images/Uninfected/C182P143NThinF_IMG_20151201_171950_cell_148.png',
#  './cell_images/Uninfected/C42P5thin_original_IMG_20150623_134919_cell_19.png',
#  './cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133205a_cell_18.png',
#  './cell_images/Uninfected/C133P94ThinF_IMG_20151004_155721_cell_53.png',
#  './cell_images/Uninfected/C86P47ThinF_IMG_20150820_124943_cell_51.png',
#  './cell_images/Parasitized/C116P77ThinF_IMG_20150930_171219_cell_113.png',
#  './cell_images/Parasitized/C128P89ThinF_IMG_20151004_131129_cell_162.png',
#  './cell_images/Parasitized/C167P128ReThinF_IMG_20151201_105559_cell_237.png',
#  './cell_images/Uninfected/C127P88ThinF_IMG_20151004_111220_cell_72.png',
#  './cell_images/Parasitized/C48P9thinF_IMG_20150721_160406_cell_239.png',
#  './cell_images/Uninfected/C47P8thinOriginalOlympusCX21_IMG_20150717_173554_cell_11.png',
#  './cell_images/Uninfected/C142P103ThinF_IMG_20151005_221931_cell_75.png',
#  './cell_images/Parasitized/C116P77ThinF_IMG_20150930_171558_cell_135.png',
#  './cell_images/Parasitized/C53P14thinF_IMG_20150726_114918_cell_176.png',
#  './cell_images/Parasitized/C118P79ThinF_IMG_20151002_110212_cell_17.png',
#  './cell_images/Uninfected/C233ThinF_IMG_20151112_160059_cell_215.png',
#  './cell_images/Parasitized/C59P20thinF_IMG_20150803_113051_cell_166.png',
#  './cell_images/Parasitized/C48P9thinF_IMG_20150721_160944_cell_223.png',
#  './cell_images/Uninfected/C189P150ThinF_IMG_20151203_142113_cell_33.png',
#  './cell_images/Parasitized/C118P79ThinF_IMG_20151002_105346_cell_158.png',
#  './cell_images/Parasitized/C50P11thinF_IMG_20150724_120553_cell_148.png',
#  './cell_images/Parasitized/C68P29N_ThinF_IMG_20150819_134504_cell_123.png',
#  './cell_images/Uninfected/C210ThinF_IMG_20151029_162934_cell_132.png',
#  './cell_images/Uninfected/C155P116ThinF_IMG_20151115_143125_cell_42.png',
#  './cell_images/Uninfected/C123P84ThinF_IMG_20151002_152330_cell_156.png',
#  './cell_images/Parasitized/C123P84ThinF_IMG_20151002_151432_cell_159.png',
#  './cell_images/Parasitized/C140P101ThinF_IMG_20151005_211735_cell_158.png',
#  './cell_images/Uninfected/C142P103ThinF_IMG_20151005_221931_cell_165.png',
#  './cell_images/Uninfected/C47P8thin_Original_Motic_IMG_20150714_093947_cell_32.png',
#  './cell_images/Parasitized/C59P20thinF_IMG_20150803_112733_cell_208.png',
#  './cell_images/Uninfected/C76P37ThinF_IMG_20150815_172902_cell_22.png',
#  './cell_images/Uninfected/C110P71ThinF_IMG_20150930_110052_cell_190.png',
#  './cell_images/Uninfected/C47P8thin_Original_Motic_IMG_20150714_093715_cell_116.png',
#  './cell_images/Parasitized/C184P145ThinF_IMG_20151203_103326_cell_141.png',
#  './cell_images/Uninfected/C178P139NThinF_IMG_20151201_154524_cell_47.png',
#  './cell_images/Uninfected/C204ThinF_IMG_20151029_110834_cell_252.png',
#  './cell_images/Parasitized/C176P137NThinF_IMG_20151201_121030_cell_21.png',
#  './cell_images/Parasitized/C50P11thinF_IMG_20150724_115651_cell_188.png',
#  './cell_images/Uninfected/C4thin_original_IMG_20150608_165908_cell_244.png',
#  './cell_images/Parasitized/C180P141NThinF_IMG_20151201_165423_cell_156.png',
#  './cell_images/Parasitized/C98P59ThinF_IMG_20150917_153030_cell_162.png',
#  './cell_images/Uninfected/C207ThinF_IMG_20151029_143952_cell_233.png',
#  './cell_images/Uninfected/C39P4thinF_original_IMG_20150622_105253_cell_1.png',
#  './cell_images/Parasitized/C99P60ThinF_IMG_20150918_141520_cell_142.png',
#  './cell_images/Uninfected/C59P20thinF_IMG_20150803_113051_cell_24.png',
#  './cell_images/Parasitized/C66P27N_ThinF_IMG_20150818_163419_cell_202.png',
#  './cell_images/Parasitized/C68P29N_ThinF_IMG_20150819_134830_cell_11.png',
#  './cell_images/Parasitized/C49P10thinF_IMG_20150724_102951_cell_213.png',
#  './cell_images/Uninfected/C102P63ThinF_IMG_20150918_163054_cell_83.png',
#  './cell_images/Parasitized/C131P92ThinF_IMG_20151004_145410_cell_132.png',
#  './cell_images/Parasitized/C63P24N_ThinF_IMG_20150818_143544_cell_176.png',
#  './cell_images/Uninfected/C235ThinF_IMG_20151112_164723_cell_273.png',
#  './cell_images/Uninfected/C213ThinF_IMG_20151106_112422_cell_168.png',
#  './cell_images/Parasitized/C175P136NThinF_IMG_20151127_142326_cell_237.png',
#  './cell_images/Parasitized/C182P143NThinF_IMG_20151201_172524_cell_187.png',
#  './cell_images/Uninfected/C93P54ThinF_IMG_20150821_162901_cell_2.png',
#  './cell_images/Uninfected/C131P92ThinF_IMG_20151004_145302_cell_76.png',
#  './cell_images/Uninfected/C79P40ThinF_IMG_20150817_104316_cell_66.png',
#  './cell_images/Parasitized/C140P101ThinF_IMG_20151005_210309_cell_188.png',
#  './cell_images/Uninfected/C143P104ThinF_IMG_20151005_230100_cell_134.png',
#  './cell_images/Uninfected/C124P85ThinF_IMG_20151002_155223_cell_56.png',
#  './cell_images/Parasitized/C113P74ThinF_IMG_20150930_135904_cell_188.png',
#  './cell_images/Uninfected/C211ThinF_IMG_20151029_164451_cell_220.png',
#  './cell_images/Uninfected/C133P94ThinF_IMG_20151004_154919_cell_4.png',
#  './cell_images/Parasitized/C82P43ThinF_IMG_20150817_123500_cell_244.png',
#  './cell_images/Uninfected/C4thin_original_IMG_20150608_170016_cell_104.png',
#  './cell_images/Parasitized/C181P142ThinF_IMG_20151127_160539_cell_190.png',
#  './cell_images/Uninfected/C161P122ThinF_IMG_20151116_101722_cell_72.png',
#  './cell_images/Uninfected/C147P108ThinF_IMG_20151115_103432_cell_167.png',
#  './cell_images/Uninfected/C98P59ThinF_IMG_20150917_153600_cell_5.png',
#  './cell_images/Parasitized/C176P137NThinF_IMG_20151201_121808_cell_124.png',
#  './cell_images/Uninfected/C46P7ThinF_IMG_20151130_205719_cell_101.png',
#  './cell_images/Uninfected/C58P19thinF_IMG_20150802_122215_cell_67.png',
#  './cell_images/Parasitized/C136P97ThinF_IMG_20151005_142437_cell_120.png',
#  './cell_images/Uninfected/C81P42ThinF_IMG_20150817_120524_cell_115.png',
#  './cell_images/Uninfected/C114P75ThinF_IMG_20150930_150013_cell_183.png',
#  './cell_images/Parasitized/C116P77ThinF_IMG_20150930_171844_cell_107.png',
#  './cell_images/Parasitized/C182P143NThinF_IMG_20151201_171836_cell_169.png',
#  './cell_images/Parasitized/C80P41ThinF_IMG_20150817_110348_cell_117.png',
#  './cell_images/Uninfected/C84P45ThinF_IMG_20150818_104156_cell_80.png',
#  './cell_images/Parasitized/C182P143NThinF_IMG_20151201_172842_cell_34.png',
#  './cell_images/Parasitized/C182P143NThinF_IMG_20151201_172216_cell_170.png',
#  './cell_images/Parasitized/C48P9thinF_IMG_20150721_160406_cell_198.png',
#  './cell_images/Parasitized/C140P101ThinF_IMG_20151005_211735_cell_152.png',
#  './cell_images/Parasitized/C137P98ThinF_IMG_20151005_160918_cell_67.png',
#  './cell_images/Parasitized/C186P147NThinF_IMG_20151203_150132_cell_195.png',
#  './cell_images/Uninfected/C158P119ThinF_IMG_20151115_183157_cell_166.png',
#  './cell_images/Uninfected/C145P106ThinF_IMG_20151016_155051_cell_142.png',
#  './cell_images/Uninfected/C128P89ThinF_IMG_20151004_130549_cell_60.png',
#  './cell_images/Uninfected/C49P10thinF_IMG_20150724_103054_cell_138.png',
#  './cell_images/Parasitized/C181P142ThinF_IMG_20151127_155722_cell_190.png',
#  './cell_images/Parasitized/C48P9thinF_IMG_20150721_161055_cell_170.png',
#  './cell_images/Uninfected/C104P65ThinF_IMG_20150918_172247_cell_125.png',
#  './cell_images/Parasitized/C133P94ThinF_IMG_20151004_155144_cell_117.png',
#  './cell_images/Uninfected/C56P17thinF_IMG_20150728_160537_cell_7.png',
#  './cell_images/Uninfected/C215ThinF_IMG_20151106_133116_cell_77.png',
#  './cell_images/Uninfected/C7NthinF_IMG_20150611_104824_cell_133.png',
#  './cell_images/Parasitized/C68P29N_ThinF_IMG_20150819_133350_cell_153.png',
#  './cell_images/Parasitized/C136P97ThinF_IMG_20151005_142437_cell_113.png',
#  './cell_images/Uninfected/C121P82ThinF_IMG_20151002_133001_cell_59.png',
#  './cell_images/Uninfected/C53P14thinF_IMG_20150726_115457_cell_11.png',
#  './cell_images/Parasitized/C45P6ThinF_IMG_20151130_160135_cell_208.png',
#  './cell_images/Parasitized/C128P89ThinF_IMG_20151004_130549_cell_146.png',
#  './cell_images/Parasitized/C180P141NThinF_IMG_20151201_165453_cell_38.png',
#  './cell_images/Uninfected/C208ThinF_IMG_20151029_155411_cell_46.png',
#  './cell_images/Parasitized/C129P90ThinF_IMG_20151004_134636_cell_29.png',
#  './cell_images/Parasitized/C139P100ThinF_IMG_20151005_182822_cell_161.png',
#  './cell_images/Parasitized/C68P29N_ThinF_IMG_20150819_134326_cell_142.png',
#  './cell_images/Uninfected/C146P107ThinF_IMG_20151018_135846_cell_173.png',
#  './cell_images/Parasitized/C182P143NThinF_IMG_20151201_171905_cell_139.png',
#  './cell_images/Uninfected/C232ThinF_IMG_20151112_154719_cell_115.png',
#  './cell_images/Parasitized/C129P90ThinF_IMG_20151004_134306_cell_133.png',
#  './cell_images/Uninfected/C115P76ThinF_IMG_20150930_163156_cell_25.png',
#  './cell_images/Parasitized/C48P9thinF_IMG_20150721_160944_cell_201.png',
#  './cell_images/Uninfected/C134P95ThinF_IMG_20151005_121048_cell_65.png',
#  './cell_images/Uninfected/C89P50ThinF_IMG_20150820_163347_cell_146.png',
#  './cell_images/Parasitized/C145P106ThinF_IMG_20151016_154719_cell_155.png',
#  './cell_images/Uninfected/C90P51ThinF_IMG_20150821_115056_cell_113.png',
#  './cell_images/Uninfected/C207ThinF_IMG_20151029_144152_cell_69.png',
#  './cell_images/Parasitized/C116P77ThinF_IMG_20150930_171954_cell_85.png',
#  './cell_images/Uninfected/C101P62ThinF_IMG_20150918_151942_cell_56.png',
#  './cell_images/Uninfected/C85P46ThinF_IMG_20150820_105154_cell_208.png',
#  './cell_images/Uninfected/C202ThinF_IMG_20151015_151254_cell_261.png',
#  './cell_images/Uninfected/C42P5thin_original_IMG_20150623_134751_cell_1.png',
#  './cell_images/Uninfected/C203ThinF_IMG_20151029_110105_cell_246.png',
#  './cell_images/Uninfected/C91P52ThinF_IMG_20150821_125154_cell_41.png',
#  './cell_images/Uninfected/C68P29N_ThinF_IMG_20150819_134112_cell_79.png',
#  './cell_images/Parasitized/C97P58ThinF_IMG_20150917_145555_cell_168.png',
#  './cell_images/Uninfected/C100P61ThinF_IMG_20150918_144823_cell_142.png',
#  './cell_images/Parasitized/C180P141NThinF_IMG_20151201_163702_cell_189.png',
#  './cell_images/Uninfected/C100P61ThinF_IMG_20150918_145042_cell_33.png',
#  './cell_images/Uninfected/C234ThinF_IMG_20151112_162759_cell_47.png',
#  './cell_images/Parasitized/C91P52ThinF_IMG_20150821_124937_cell_194.png',
#  './cell_images/Parasitized/C79P40ThinF_IMG_20150817_103901_cell_122.png',
#  './cell_images/Uninfected/C63P24N_ThinF_IMG_20150818_143319_cell_103.png',
#  './cell_images/Uninfected/C65P26N_ThinF_IMG_20150818_154050_cell_168.png',
#  './cell_images/Parasitized/C126P87ThinF_IMG_20151004_105100_cell_136.png',
#  './cell_images/Uninfected/C233ThinF_IMG_20151112_161119_cell_277.png',
#  './cell_images/Parasitized/C137P98ThinF_IMG_20151005_162010_cell_80.png',
#  './cell_images/Uninfected/C138P99ThinF_IMG_20151005_173453_cell_112.png',
#  './cell_images/Uninfected/C157P118ThinF_IMG_20151115_162818_cell_86.png',
#  './cell_images/Parasitized/C80P41ThinF_IMG_20150817_110348_cell_122.png',
#  './cell_images/Parasitized/C131P92ThinF_IMG_20151004_145224_cell_128.png',
#  './cell_images/Parasitized/C50P11thinF_IMG_20150724_115651_cell_189.png',
#  './cell_images/Parasitized/C48P9thinF_IMG_20150721_164031_cell_23.png',
#  './cell_images/Uninfected/C235ThinF_IMG_20151112_164834_cell_259.png',
#  './cell_images/Parasitized/C45P6ThinF_IMG_20151130_160409_cell_200.png',
#  './cell_images/Parasitized/C101P62ThinF_IMG_20150923_165215_cell_35.png',
#  './cell_images/Uninfected/C92P53ThinF_IMG_20150821_150718_cell_144.png',
#  './cell_images/Parasitized/C179P140ThinF_IMG_20151127_153350_cell_180.png',
#  './cell_images/Uninfected/C155P116ThinF_IMG_20151115_142526_cell_36.png',
#  './cell_images/Parasitized/C76P37ThinF_IMG_20150815_172808_cell_222.png',
#  './cell_images/Parasitized/C101P62ThinF_IMG_20150918_151942_cell_61.png',
#  './cell_images/Parasitized/C136P97ThinF_IMG_20151005_141803_cell_128.png',
#  './cell_images/Parasitized/C48P9thinF_IMG_20150721_164129_cell_6.png',
#  './cell_images/Parasitized/C186P147NThinF_IMG_20151203_150408_cell_166.png',
#  './cell_images/Uninfected/C71P32_ThinF_IMG_20150813_162554_cell_83.png',
#  './cell_images/Uninfected/C137P98ThinF_IMG_20151005_160918_cell_47.png',
#  './cell_images/Parasitized/C63P24N_ThinF_IMG_20150818_142948_cell_169.png',
#  './cell_images/Parasitized/C60P21thinF_IMG_20150804_105955_cell_128.png',
#  './cell_images/Uninfected/C184P145ThinF_IMG_20151203_102405_cell_45.png',
#  './cell_images/Uninfected/C126P87ThinF_IMG_20151004_104813_cell_107.png',
#  './cell_images/Uninfected/C132P93ThinF_IMG_20151004_152353_cell_10.png',
#  './cell_images/Uninfected/C225ThinF_IMG_20151112_113915_cell_12.png',
#  './cell_images/Parasitized/C39P4thinF_original_IMG_20150622_105803_cell_86.png',
#  './cell_images/Parasitized/C180P141NThinF_IMG_20151201_165453_cell_56.png',
#  './cell_images/Parasitized/C116P77ThinF_IMG_20150930_171448_cell_98.png',
#  './cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_199.png',
#  './cell_images/Parasitized/C178P139NThinF_IMG_20151201_154025_cell_128.png',
#  './cell_images/Uninfected/C160P121ThinF_IMG_20151116_094338_cell_30.png',
#  './cell_images/Uninfected/C56P17thinF_IMG_20150728_151330_cell_68.png',
#  './cell_images/Parasitized/C99P60ThinF_IMG_20150918_141001_cell_167.png',
#  './cell_images/Uninfected/C114P75ThinF_IMG_20150930_150145_cell_1.png',
#  './cell_images/Uninfected/C202ThinF_IMG_20151015_152200_cell_20.png',
#  './cell_images/Uninfected/C110P71ThinF_IMG_20150930_105925_cell_86.png',
#  './cell_images/Parasitized/C175P136NThinF_IMG_20151127_142009_cell_215.png',
#  './cell_images/Uninfected/C64P25N_ThinF_IMG_20150818_153401_cell_70.png',
#  './cell_images/Uninfected/C54P15thinF_IMG_20150728_102017_cell_192.png',
#  './cell_images/Uninfected/C220ThinF_IMG_20151106_154016_cell_1.png',
#  './cell_images/Parasitized/C70P31_ThinF_IMG_20150819_141403_cell_99.png',
#  './cell_images/Uninfected/C109P70ThinF_IMG_20150930_102716_cell_30.png',
#  './cell_images/Uninfected/C50P11thinF_IMG_20150724_120553_cell_48.png',
#  './cell_images/Parasitized/C180P141NThinF_IMG_20151201_165423_cell_171.png',
#  './cell_images/Uninfected/C91P52ThinF_IMG_20150821_124739_cell_11.png',
#  './cell_images/Uninfected/C111P72ThinF_IMG_20150930_113049_cell_66.png',
#  './cell_images/Parasitized/C167P128ReThinF_IMG_20151201_110011_cell_233.png',
#  './cell_images/Uninfected/C67P28N_ThinF_IMG_20150819_133000_cell_52.png',
#  './cell_images/Parasitized/C140P101ThinF_IMG_20151005_210309_cell_184.png',
#  './cell_images/Parasitized/C99P60ThinF_IMG_20150918_140900_cell_132.png',
#  './cell_images/Parasitized/C48P9thinF_IMG_20150721_163810_cell_10.png',
#  './cell_images/Parasitized/C91P52ThinF_IMG_20150821_123116_cell_186.png',
#  './cell_images/Uninfected/C94P55ThinF_IMG_20150821_170249_cell_16.png',
#  './cell_images/Uninfected/C130P91ThinF_IMG_20151004_141341_cell_88.png',
#  './cell_images/Uninfected/C91P52ThinF_IMG_20150821_124739_cell_4.png',
#  './cell_images/Parasitized/C118P79ThinF_IMG_20151002_110834_cell_145.png',
#  './cell_images/Parasitized/C177P138NThinF_IMG_20151201_143704_cell_181.png',
#  './cell_images/Uninfected/C154P115ThinF_IMG_20151115_141621_cell_69.png',
#  './cell_images/Parasitized/C68P29N_ThinF_IMG_20150819_134112_cell_141.png',
#  './cell_images/Parasitized/C102P63ThinF_IMG_20150918_162155_cell_132.png',
#  './cell_images/Uninfected/C153P114ThinF_IMG_20151115_135832_cell_193.png',
#  './cell_images/Uninfected/C226ThinF_IMG_20151112_131622_cell_162.png',
#  './cell_images/Uninfected/C127P88ThinF_IMG_20151004_111220_cell_65.png',
#  './cell_images/Parasitized/C99P60ThinF_IMG_20150918_141620_cell_2.png',
#  './cell_images/Parasitized/C143P104ThinF_IMG_20151005_225746_cell_174.png',
#  './cell_images/Parasitized/C59P20thinF_IMG_20150803_112733_cell_215.png',
#  './cell_images/Uninfected/C206ThinF_IMG_20151029_140917_cell_103.png',
#  './cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_173.png',
#  './cell_images/Uninfected/C163P124ThinF_IMG_20151116_110921_cell_49.png',
#  './cell_images/Parasitized/C183P144NThinF_IMG_20151201_223758_cell_130.png',
#  './cell_images/Uninfected/C231ThinF_IMG_20151112_153359_cell_185.png',
#  './cell_images/Uninfected/C60P21thinF_IMG_20150804_105955_cell_1.png',
#  './cell_images/Uninfected/C165P126ThinF_IMG_20151117_172859_cell_46.png',
#  './cell_images/Parasitized/C99P60ThinF_IMG_20150918_141129_cell_116.png',
#  './cell_images/Parasitized/C101P62ThinF_IMG_20150923_165215_cell_32.png',
#  './cell_images/Parasitized/C118P79ThinF_IMG_20151002_105125_cell_163.png',
#  './cell_images/Uninfected/C33P1thinF_IMG_20150619_120645a_cell_26.png',
#  './cell_images/Parasitized/C97P58ThinF_IMG_20150917_151903_cell_10.png',
#  './cell_images/Parasitized/C51AP12thinF_IMG_20150724_154330_cell_113.png',
#  './cell_images/Parasitized/C180P141NThinF_IMG_20151201_165528_cell_148.png',
#  './cell_images/Uninfected/C125P86ThinF_IMG_20151004_101929_cell_131.png',
#  './cell_images/Parasitized/C89P50ThinF_IMG_20150820_163728_cell_200.png',
#  './cell_images/Parasitized/C181P142ThinF_IMG_20151127_160650_cell_182.png',
#  './cell_images/Parasitized/C68P29N_ThinF_IMG_20150819_134830_cell_2.png',
#  './cell_images/Uninfected/C47P8thinOriginalOlympusCX21_IMG_20150717_173554_cell_143.png',
#  './cell_images/Uninfected/C115P76ThinF_IMG_20150930_163018_cell_157.png',
#  './cell_images/Parasitized/C146P107ThinF_IMG_20151018_135846_cell_220.png',
#  './cell_images/Parasitized/C51AP12thinF_IMG_20150724_153313_cell_101.png',
#  './cell_images/Parasitized/C66P27N_ThinF_IMG_20150818_163419_cell_204.png',
#  './cell_images/Uninfected/C49P10thinF_IMG_20150724_103233_cell_105.png',
#  './cell_images/Parasitized/C99P60ThinF_IMG_20150918_141620_cell_7.png',
#  './cell_images/Parasitized/C182P143NThinF_IMG_20151201_171950_cell_192.png',
#  './cell_images/Uninfected/C64P25N_ThinF_IMG_20150818_153517_cell_145.png',
#  './cell_images/Parasitized/C184P145ThinF_IMG_20151203_102405_cell_164.png',
#  './cell_images/Uninfected/C88P49ThinF_IMG_20150820_151451_cell_89.png',
#  './cell_images/Uninfected/C123P84ThinF_IMG_20151002_150931_cell_162.png',
#  './cell_images/Parasitized/C145P106ThinF_IMG_20151016_154719_cell_158.png',
#  './cell_images/Parasitized/C188P149ThinF_IMG_20151203_135433_cell_181.png',
#  './cell_images/Parasitized/C84P45ThinF_IMG_20150818_102800_cell_8.png',
#  './cell_images/Uninfected/C70P31_ThinF_IMG_20150819_142744_cell_86.png',
#  './cell_images/Parasitized/C182P143NThinF_IMG_20151201_172759_cell_22.png',
#  './cell_images/Parasitized/C159P120ThinF_IMG_20151115_190812_cell_242.png',
#  './cell_images/Uninfected/C169P130ThinF_IMG_20151119_144354_cell_116.png',
#  './cell_images/Parasitized/C91P52ThinF_IMG_20150821_124311_cell_14.png',
#  './cell_images/Parasitized/C45P6ThinF_IMG_20151130_160409_cell_199.png',
#  './cell_images/Parasitized/C65P26N_ThinF_IMG_20150818_154326_cell_184.png',
#  './cell_images/Parasitized/C140P101ThinF_IMG_20151005_205922_cell_189.png',
#  './cell_images/Uninfected/C139P100ThinF_IMG_20151005_182527_cell_6.png',
#  './cell_images/Uninfected/C140P101ThinF_IMG_20151005_211735_cell_105.png',
#  './cell_images/Uninfected/C184P145ThinF_IMG_20151203_102543_cell_87.png',
#  './cell_images/Parasitized/C68P29N_ThinF_IMG_20150819_134326_cell_119.png',
#  './cell_images/Uninfected/C113P74ThinF_IMG_20150930_134614_cell_81.png',
#  './cell_images/Parasitized/C132P93ThinF_IMG_20151004_151811_cell_158.png',
#  './cell_images/Parasitized/C48P9thinF_IMG_20150721_164304_cell_17.png',
#  './cell_images/Uninfected/C154P115ThinF_IMG_20151115_141507_cell_171.png',
#  './cell_images/Uninfected/C113P74ThinF_IMG_20150930_135904_cell_162.png',
#  './cell_images/Uninfected/C206ThinF_IMG_20151029_140511_cell_199.png',
#  './cell_images/Parasitized/C145P106ThinF_IMG_20151016_154921_cell_147.png',
#  './cell_images/Uninfected/C51AP12thinF_IMG_20150724_155557_cell_15.png',
#  './cell_images/Uninfected/C84P45ThinF_IMG_20150818_101550_cell_60.png',
#  './cell_images/Uninfected/C206ThinF_IMG_20151029_140511_cell_54.png',
#  './cell_images/Uninfected/C153P114ThinF_IMG_20151115_140242_cell_152.png',
#  './cell_images/Uninfected/C75P36_ThinF_IMG_20150815_163015_cell_40.png',
#  './cell_images/Uninfected/C53P14thinF_IMG_20150726_114606_cell_117.png',
#  './cell_images/Uninfected/C157P118ThinF_IMG_20151115_163915_cell_85.png',
#  './cell_images/Uninfected/C127P88ThinF_IMG_20151004_111526_cell_93.png',
#  './cell_images/Uninfected/C121P82ThinF_IMG_20151002_133739_cell_38.png',
#  './cell_images/Parasitized/C176P137NThinF_IMG_20151201_121808_cell_127.png',
#  './cell_images/Parasitized/C180P141NThinF_IMG_20151201_165601_cell_163.png',
#  './cell_images/Uninfected/C108P69ThinF_IMG_20150924_224038_cell_36.png',
#  './cell_images/Parasitized/C101P62ThinF_IMG_20150918_151239_cell_79.png',
#  './cell_images/Parasitized/C80P41ThinF_IMG_20150817_111544_cell_130.png',
#  './cell_images/Parasitized/C155P116ThinF_IMG_20151115_142805_cell_195.png',
#  './cell_images/Uninfected/C100P61ThinF_IMG_20150918_144348_cell_25.png',
#  './cell_images/Parasitized/C97P58ThinF_IMG_20150917_151903_cell_11.png',
#  './cell_images/Parasitized/C137P98ThinF_IMG_20151005_162010_cell_77.png',
#  './cell_images/Parasitized/C45P6ThinF_IMG_20151130_160241_cell_201.png',
#  './cell_images/Uninfected/C143P104ThinF_IMG_20151005_225623_cell_71.png',
#  './cell_images/Parasitized/C59P20thinF_IMG_20150803_113430_cell_45.png',
#  './cell_images/Uninfected/C88P49ThinF_IMG_20150820_150141_cell_167.png',
#  './cell_images/Parasitized/C181P142ThinF_IMG_20151127_160539_cell_199.png',
#  './cell_images/Uninfected/C64P25N_ThinF_IMG_20150818_153517_cell_40.png',
#  './cell_images/Parasitized/C116P77ThinF_IMG_20150930_171844_cell_112.png',
#  './cell_images/Uninfected/C170P131ThinF_IMG_20151119_120111_cell_44.png',
#  './cell_images/Parasitized/C59P20thinF_IMG_20150803_112733_cell_199.png',
#  './cell_images/Parasitized/C180P141NThinF_IMG_20151201_165453_cell_59.png',
#  './cell_images/Uninfected/C221ThinF_IMG_20151106_160022_cell_101.png',
#  './cell_images/Parasitized/C132P93ThinF_IMG_20151004_152808_cell_9.png',
#  './cell_images/Parasitized/C99P60ThinF_IMG_20150918_141314_cell_118.png',
#  './cell_images/Uninfected/C141P102ThinF_IMG_20151005_215906_cell_84.png',
#  './cell_images/Uninfected/C172P133ThinF_IMG_20151119_155307_cell_217.png',
#  './cell_images/Parasitized/C176P137NThinF_IMG_20151201_120612_cell_22.png',
#  './cell_images/Parasitized/C46P7ThinF_IMG_20151130_210815_cell_3.png',
#  './cell_images/Parasitized/C116P77ThinF_IMG_20150930_171809_cell_78.png',
#  './cell_images/Uninfected/C217ThinF_IMG_20151106_141500_cell_23.png',
#  './cell_images/Uninfected/C169P130ThinF_IMG_20151118_173039_cell_172.png',
#  './cell_images/Uninfected/C95P56ThinF_IMG_20150821_171530_cell_14.png',
#  './cell_images/Parasitized/C46P7ThinF_IMG_20151130_210743_cell_157.png',
#  './cell_images/Parasitized/C81P42ThinF_IMG_20150817_121113_cell_182.png',
#  './cell_images/Uninfected/C61P22N_ThinF_IMG_20150818_112252_cell_87.png',
#  './cell_images/Uninfected/C171P132ThinF_IMG_20151119_152913_cell_117.png',
#  './cell_images/Parasitized/C182P143NThinF_IMG_20151201_172607_cell_38.png',
#  './cell_images/Uninfected/C167P128ReThinF_IMG_20151201_105707_cell_84.png',
#  './cell_images/Uninfected/C202ThinF_IMG_20151015_152200_cell_23.png',
#  './cell_images/Uninfected/C47P8thinOriginalOlympusCX21_IMG_20150717_174844_cell_72.png',
#  './cell_images/Uninfected/C49P10thinF_IMG_20150724_102330_cell_181.png',
#  './cell_images/Uninfected/C108P69ThinF_IMG_20150924_224038_cell_174.png',
#  './cell_images/Uninfected/C229ThinF_IMG_20151112_144613_cell_155.png',
#  './cell_images/Parasitized/C99P60ThinF_IMG_20150918_142334_cell_11.png',
#  './cell_images/Uninfected/C164P125ThinF_IMG_20151116_120135_cell_81.png',
#  './cell_images/Parasitized/C59P20thinF_IMG_20150803_112858_cell_164.png',
#  './cell_images/Parasitized/C84P45ThinF_IMG_20150818_102800_cell_12.png',
#  './cell_images/Parasitized/C180P141NThinF_IMG_20151201_165659_cell_46.png',
#  './cell_images/Uninfected/C97P58ThinF_IMG_20150917_151551_cell_147.png',
#  './cell_images/Parasitized/C131P92ThinF_IMG_20151004_151126_cell_122.png',
#  './cell_images/Uninfected/C112P73ThinF_IMG_20150930_131254_cell_167.png',
#  './cell_images/Uninfected/C33P1thinF_IMG_20150619_121411a_cell_139.png',
#  './cell_images/Parasitized/C59P20thinF_IMG_20150803_113139_cell_41.png',
#  './cell_images/Uninfected/C144P105ThinF_IMG_20151015_163142_cell_66.png',
#  './cell_images/Parasitized/C133P94ThinF_IMG_20151004_154351_cell_100.png',
#  './cell_images/Uninfected/C107P68ThinF_IMG_20150924_222535_cell_123.png',
#  './cell_images/Parasitized/C133P94ThinF_IMG_20151004_155012_cell_13.png',
#  './cell_images/Parasitized/C183P144NThinF_IMG_20151201_223758_cell_136.png',
#  './cell_images/Parasitized/C123P84ThinF_IMG_20151002_151432_cell_171.png',
#  './cell_images/Parasitized/C93P54ThinF_IMG_20150821_162641_cell_221.png',
#  './cell_images/Uninfected/C125P86ThinF_IMG_20151004_102205_cell_101.png',
#  './cell_images/Parasitized/C80P41ThinF_IMG_20150817_110957_cell_142.png',
#  './cell_images/Parasitized/C179P140ThinF_IMG_20151127_153453_cell_180.png',
#  './cell_images/Parasitized/C101P62ThinF_IMG_20150923_170344_cell_83.png',
#  './cell_images/Parasitized/C126P87ThinF_IMG_20151004_104728_cell_131.png',
#  './cell_images/Parasitized/C59P20thinF_IMG_20150803_115303_cell_15.png',
#  './cell_images/Uninfected/C150P111ThinF_IMG_20151115_120029_cell_160.png',
#  './cell_images/Parasitized/C48P9thinF_IMG_20150721_164304_cell_31.png',
#  './cell_images/Uninfected/C178P139NThinF_IMG_20151201_154025_cell_80.png',
#  './cell_images/Parasitized/C98P59ThinF_IMG_20150917_154452_cell_202.png',
#  './cell_images/Parasitized/C68P29N_ThinF_IMG_20150819_133236_cell_210.png',
#  './cell_images/Uninfected/C111P72ThinF_IMG_20150930_112827_cell_37.png',
#  './cell_images/Uninfected/C172P133ThinF_IMG_20151119_155343_cell_173.png',
#  './cell_images/Parasitized/C172P133ThinF_IMG_20151119_155343_cell_288.png',
#  './cell_images/Uninfected/C117P78ThinF_IMG_20150930_221927_cell_67.png',
#  './cell_images/Uninfected/C42P5thin_original_IMG_20150623_134919_cell_74.png',
#  './cell_images/Parasitized/C166P127ThinF_IMG_20151117_195030_cell_220.png',
#  './cell_images/Uninfected/C71P32_ThinF_IMG_20150813_161634_cell_58.png',
#  './cell_images/Parasitized/C167P128ReThinF_IMG_20151201_105354_cell_228.png',
#  './cell_images/Parasitized/C115P76ThinF_IMG_20150930_162038_cell_208.png',
#  './cell_images/Parasitized/C100P61ThinF_IMG_20150918_145042_cell_167.png',
#  './cell_images/Uninfected/C72P33_ThinF_IMG_20150815_104923_cell_156.png',
#  './cell_images/Parasitized/C132P93ThinF_IMG_20151004_152642_cell_49.png',
#  './cell_images/Uninfected/C80P41ThinF_IMG_20150817_110608_cell_138.png',
#  './cell_images/Parasitized/C182P143NThinF_IMG_20151201_171905_cell_162.png',
#  './cell_images/Parasitized/C136P97ThinF_IMG_20151005_141803_cell_133.png',
#  './cell_images/Uninfected/C201ThinF_IMG_20150930_143502_cell_237.png',
#  './cell_images/Parasitized/C132P93ThinF_IMG_20151004_152257_cell_115.png',
#  './cell_images/Parasitized/C137P98ThinF_IMG_20151005_163218_cell_83.png',
#  './cell_images/Uninfected/C76P37ThinF_IMG_20150815_171214_cell_39.png',
#  './cell_images/Uninfected/C169P130ThinF_IMG_20151119_143039_cell_158.png',
#  './cell_images/Parasitized/C81P42ThinF_IMG_20150817_120351_cell_179.png',
#  './cell_images/Uninfected/C240ThinF_IMG_20151127_115328_cell_7.png',
#  './cell_images/Uninfected/C154P115ThinF_IMG_20151115_141507_cell_198.png',
#  './cell_images/Uninfected/C167P128ReThinF_IMG_20151201_110011_cell_106.png',
#  './cell_images/Parasitized/C182P143NThinF_IMG_20151201_171950_cell_177.png',
#  './cell_images/Uninfected/C151P112ThinF_IMG_20151115_121942_cell_41.png',
#  './cell_images/Parasitized/C65P26N_ThinF_IMG_20150818_154624_cell_205.png',
#  './cell_images/Parasitized/C129P90ThinF_IMG_20151004_134306_cell_138.png',
#  './cell_images/Uninfected/C217ThinF_IMG_20151106_141326_cell_20.png',
#  './cell_images/Uninfected/C222ThinF_IMG_20151115_150728_cell_43.png',
#  './cell_images/Uninfected/C201ThinF_IMG_20150930_143411_cell_134.png',
#  './cell_images/Parasitized/C116P77ThinF_IMG_20150930_171219_cell_104.png',
#  './cell_images/Uninfected/C158P119ThinF_IMG_20151115_181035_cell_93.png',
#  './cell_images/Uninfected/C173P134NThinF_IMG_20151130_120046_cell_8.png',
#  './cell_images/Parasitized/C76P37ThinF_IMG_20150815_172808_cell_227.png',
#  './cell_images/Parasitized/C137P98ThinF_IMG_20151005_161659_cell_16.png',
#  './cell_images/Parasitized/C91P52ThinF_IMG_20150821_124504_cell_191.png',
#  './cell_images/Uninfected/C81P42ThinF_IMG_20150817_120856_cell_7.png',
#  './cell_images/Parasitized/C156P117ThinF_IMG_20151115_154435_cell_297.png',
#  './cell_images/Parasitized/C68P29N_ThinF_IMG_20150819_134830_cell_47.png',
#  './cell_images/Uninfected/C105P66ThinF_IMG_20150924_100655_cell_64.png',
#  './cell_images/Parasitized/C144P105ThinF_IMG_20151015_163432_cell_314.png',
#  './cell_images/Uninfected/C106P67ThinF_IMG_20150924_103245_cell_24.png',
#  './cell_images/Parasitized/C176P137NThinF_IMG_20151201_122811_cell_168.png',
#  './cell_images/Uninfected/C121P82ThinF_IMG_20151002_134014_cell_63.png',
#  './cell_images/Uninfected/C52P13thinF_IMG_20150725_125847_cell_27.png',
#  './cell_images/Parasitized/C59P20thinF_IMG_20150803_113139_cell_4.png',
#  './cell_images/Uninfected/C176P137NThinF_IMG_20151201_122444_cell_72.png',
#  './cell_images/Parasitized/C137P98ThinF_IMG_20151005_155704_cell_65.png',
#  './cell_images/Parasitized/C184P145ThinF_IMG_20151203_103114_cell_158.png',
#  './cell_images/Uninfected/C234ThinF_IMG_20151112_162909_cell_7.png',
#  './cell_images/Parasitized/C136P97ThinF_IMG_20151005_143743_cell_115.png',
#  './cell_images/Parasitized/C116P77ThinF_IMG_20150930_171739_cell_87.png',
#  './cell_images/Uninfected/C123P84ThinF_IMG_20151002_152144_cell_113.png',
#  './cell_images/Parasitized/C182P143NThinF_IMG_20151201_172759_cell_31.png',
#  './cell_images/Uninfected/C2NThinF_IMG_20150604_114751_cell_181.png',
#  './cell_images/Uninfected/C98P59ThinF_IMG_20150917_153030_cell_62.png',
#  './cell_images/Parasitized/C133P94ThinF_IMG_20151004_155912_cell_6.png',
#  './cell_images/Parasitized/C137P98ThinF_IMG_20151005_155704_cell_67.png',
#  './cell_images/Uninfected/C225ThinF_IMG_20151112_113953_cell_43.png',
#  './cell_images/Parasitized/C132P93ThinF_IMG_20151004_152353_cell_136.png',
#  './cell_images/Parasitized/C118P79ThinF_IMG_20151002_110002_cell_6.png',
#  './cell_images/Parasitized/C116P77ThinF_IMG_20150930_171558_cell_142.png',
#  './cell_images/Uninfected/C105P66ThinF_IMG_20150924_094800_cell_63.png',
#  './cell_images/Uninfected/C88P49ThinF_IMG_20150820_151451_cell_158.png',
#  './cell_images/Parasitized/C128P89ThinF_IMG_20151004_131231_cell_159.png',
#  './cell_images/Uninfected/C230ThinF_IMG_20151112_150329_cell_222.png',
#  './cell_images/Parasitized/C99P60ThinF_IMG_20150918_141520_cell_87.png',
#  './cell_images/Uninfected/C99P60ThinF_IMG_20150918_140900_cell_69.png',
#  './cell_images/Parasitized/C133P94ThinF_IMG_20151004_155144_cell_135.png',
#  './cell_images/Uninfected/C138P99ThinF_IMG_20151005_171940_cell_26.png',
#  './cell_images/Uninfected/C52P13thinF_IMG_20150725_124830_cell_115.png',
#  './cell_images/Parasitized/C132P93ThinF_IMG_20151004_152808_cell_8.png',
#  './cell_images/Uninfected/C108P69ThinF_IMG_20150924_224909_cell_47.png',
#  './cell_images/Parasitized/C68P29N_ThinF_IMG_20150819_134326_cell_132.png',
#  './cell_images/Uninfected/C168P129ThinF_IMG_20151118_155802_cell_1.png',
#  './cell_images/Uninfected/C176P137NThinF_IMG_20151201_120845_cell_78.png',
#  './cell_images/Parasitized/C70P31_ThinF_IMG_20150813_131708_cell_5.png',
#  './cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_100.png',
#  './cell_images/Uninfected/C93P54ThinF_IMG_20150821_163815_cell_197.png',
#  './cell_images/Uninfected/C127P88ThinF_IMG_20151004_111755_cell_28.png',
#  './cell_images/Parasitized/C182P143NThinF_IMG_20151201_172842_cell_28.png',
#  './cell_images/Parasitized/C189P150ThinF_IMG_20151203_141809_cell_90.png',
#  './cell_images/Uninfected/C231ThinF_IMG_20151112_153246_cell_23.png',
#  './cell_images/Parasitized/C89P50ThinF_IMG_20150820_163728_cell_189.png',
#  './cell_images/Uninfected/C154P115ThinF_IMG_20151115_141837_cell_161.png',
#  './cell_images/Uninfected/C120P81ThinF_IMG_20151002_131120_cell_17.png',
#  './cell_images/Uninfected/C207ThinF_IMG_20151029_143711_cell_82.png',
#  './cell_images/Parasitized/C132P93ThinF_IMG_20151004_152505_cell_153.png',
#  './cell_images/Parasitized/C132P93ThinF_IMG_20151004_152808_cell_23.png',
#  './cell_images/Uninfected/C90P51ThinF_IMG_20150821_115700_cell_252.png',
#  './cell_images/Uninfected/C220ThinF_IMG_20151106_154533_cell_85.png',
#  './cell_images/Uninfected/C132P93ThinF_IMG_20151004_151701_cell_123.png',
#  './cell_images/Uninfected/C89P50ThinF_IMG_20150820_163347_cell_195.png',
#  './cell_images/Parasitized/C180P141NThinF_IMG_20151201_170110_cell_18.png',
#  './cell_images/Uninfected/C218ThinF_IMG_20151106_143940_cell_168.png',
#  './cell_images/Parasitized/C84P45ThinF_IMG_20150818_102009_cell_7.png',
#  './cell_images/Uninfected/C189P150ThinF_IMG_20151203_141004_cell_14.png',
#  './cell_images/Uninfected/C226ThinF_IMG_20151112_131408_cell_158.png',
#  './cell_images/Parasitized/C95P56ThinF_IMG_20150821_172351_cell_104.png',
#  './cell_images/Parasitized/C131P92ThinF_IMG_20151004_145224_cell_132.png',
#  './cell_images/Parasitized/C182P143NThinF_IMG_20151201_172057_cell_154.png',
#  './cell_images/Uninfected/C185P146ThinF_IMG_20151203_110817_cell_170.png',
#  './cell_images/Parasitized/C168P129ThinF_IMG_20151118_160516_cell_178.png',
#  './cell_images/Parasitized/C117P78ThinF_IMG_20150930_214629_cell_106.png',
#  './cell_images/Uninfected/C129P90ThinF_IMG_20151004_134520_cell_92.png',
#  './cell_images/Parasitized/C110P71ThinF_IMG_20150930_105319_cell_185.png',
#  './cell_images/Parasitized/C39P4thinF_original_IMG_20150622_105253_cell_110.png',
#  './cell_images/Uninfected/C64P25N_ThinF_IMG_20150818_152337_cell_93.png',
#  './cell_images/Parasitized/C117P78ThinF_IMG_20150930_214138_cell_96.png',
#  './cell_images/Parasitized/C99P60ThinF_IMG_20150918_142128_cell_108.png',
#  './cell_images/Parasitized/C140P101ThinF_IMG_20151005_210309_cell_192.png',
#  './cell_images/Parasitized/C65P26N_ThinF_IMG_20150818_154050_cell_177.png',
#  './cell_images/Uninfected/C216ThinF_IMG_20151106_135228_cell_153.png',
#  './cell_images/Uninfected/C109P70ThinF_IMG_20150930_102716_cell_33.png',
#  './cell_images/Parasitized/C133P94ThinF_IMG_20151004_154919_cell_123.png',
#  './cell_images/Parasitized/C70P31_ThinF_IMG_20150819_142703_cell_1.png',
#  './cell_images/Uninfected/C158P119ThinF_IMG_20151115_181859_cell_149.png',
#  './cell_images/Parasitized/C48P9thinF_IMG_20150721_160406_cell_246.png',
#  './cell_images/Uninfected/C156P117ThinF_IMG_20151115_153831_cell_148.png',
#  './cell_images/Parasitized/C181P142ThinF_IMG_20151127_155914_cell_186.png',
#  './cell_images/Parasitized/C82P43ThinF_IMG_20150817_123500_cell_235.png',
#  './cell_images/Parasitized/C99P60ThinF_IMG_20150918_141314_cell_121.png',
#  './cell_images/Parasitized/C68P29N_ThinF_IMG_20150819_134625_cell_36.png',
#  './cell_images/Uninfected/C207ThinF_IMG_20151029_144152_cell_284.png',
#  './cell_images/Uninfected/C162P123ThinF_IMG_20151116_104342_cell_133.png',
#  './cell_images/Parasitized/C92P53ThinF_IMG_20150821_151646_cell_203.png',
#  './cell_images/Uninfected/C241NThinF_IMG_20151207_124608_cell_125.png',
#  './cell_images/Parasitized/C170P131ThinF_IMG_20151119_120150_cell_223.png',
#  './cell_images/Parasitized/C68P29N_ThinF_IMG_20150819_134326_cell_162.png',
#  './cell_images/Uninfected/C222ThinF_IMG_20151115_151015_cell_76.png',
#  './cell_images/Parasitized/C129P90ThinF_IMG_20151004_133921_cell_122.png',
#  './cell_images/Uninfected/C39P4thinF_original_IMG_20150622_105253_cell_10.png',
#  './cell_images/Uninfected/C129P90ThinF_IMG_20151004_133329_cell_91.png',
#  './cell_images/Parasitized/C184P145ThinF_IMG_20151203_103637_cell_170.png',
#  './cell_images/Uninfected/C105P66ThinF_IMG_20150924_094800_cell_70.png',
#  './cell_images/Parasitized/C48P9thinF_IMG_20150721_163810_cell_8.png',
#  './cell_images/Uninfected/C226ThinF_IMG_20151112_131622_cell_42.png',
#  './cell_images/Uninfected/C82P43ThinF_IMG_20150817_124418_cell_107.png',
#  './cell_images/Parasitized/C67P28N_ThinF_IMG_20150819_115417_cell_178.png',
#  './cell_images/Parasitized/C39P4thinF_original_IMG_20150622_111206_cell_98.png',
#  './cell_images/Parasitized/C180P141NThinF_IMG_20151201_165528_cell_182.png',
#  './cell_images/Parasitized/C33P1thinF_IMG_20150619_115808a_cell_205.png',
#  './cell_images/Parasitized/C48P9thinF_IMG_20150721_162732_cell_17.png',
#  './cell_images/Parasitized/C136P97ThinF_IMG_20151005_141803_cell_112.png',
#  './cell_images/Uninfected/C94P55ThinF_IMG_20150821_170403_cell_30.png',
#  './cell_images/Parasitized/C59P20thinF_IMG_20150803_113430_cell_8.png',
#  './cell_images/Uninfected/C63P24N_ThinF_IMG_20150818_143319_cell_107.png',
#  './cell_images/Parasitized/C176P137NThinF_IMG_20151201_122811_cell_149.png',
#  './cell_images/Parasitized/C81P42ThinF_IMG_20150817_120351_cell_182.png',
#  './cell_images/Uninfected/C177P138NThinF_IMG_20151201_143704_cell_125.png',
#  './cell_images/Parasitized/C184P145ThinF_IMG_20151203_103824_cell_131.png',
#  './cell_images/Parasitized/C137P98ThinF_IMG_20151005_160918_cell_71.png',
#  './cell_images/Uninfected/C137P98ThinF_IMG_20151005_163901_cell_51.png',
#  './cell_images/Parasitized/C173P134NThinF_IMG_20151130_115339_cell_260.png',
#  './cell_images/Uninfected/C149P110ThinF_IMG_20151115_114729_cell_179.png',
#  './cell_images/Parasitized/C60P21thinF_IMG_20150803_144003_cell_125.png',
#  './cell_images/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_132.png',
#  './cell_images/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_127.png',
#  './cell_images/Parasitized/C120P81ThinF_IMG_20151002_130150_cell_208.png',
#  './cell_images/Uninfected/C169P130ThinF_IMG_20151119_143039_cell_182.png',
#  './cell_images/Parasitized/C84P45ThinF_IMG_20150818_104156_cell_125.png',
#  './cell_images/Parasitized/C60P21thinF_IMG_20150804_105639_cell_11.png',
#  './cell_images/Uninfected/C53P14thinF_IMG_20150726_115457_cell_29.png',
#  './cell_images/Uninfected/C175P136NThinF_IMG_20151127_142326_cell_90.png',
#  './cell_images/Parasitized/C132P93ThinF_IMG_20151004_152505_cell_160.png',
#  './cell_images/Parasitized/C175P136NThinF_IMG_20151127_141253_cell_247.png',
#  './cell_images/Uninfected/C63P24N_ThinF_IMG_20150818_143423_cell_127.png',
#  './cell_images/Uninfected/C148P109ThinF_IMG_20151115_112333_cell_98.png',
#  './cell_images/Uninfected/C78P39ThinF_IMG_20150606_103413_cell_116.png',
#  './cell_images/Uninfected/C2NThinF_IMG_20150604_114631_cell_72.png',
#  './cell_images/Uninfected/C55P16thinF_IMG_20150728_124508_cell_139.png',
#  './cell_images/Uninfected/C81P42ThinF_IMG_20150817_120524_cell_162.png',
#  './cell_images/Parasitized/C39P4thinF_original_IMG_20150622_113632_cell_6.png',
#  './cell_images/Uninfected/C62P23N_ThinF_IMG_20150818_133211_cell_43.png',
#  './cell_images/Uninfected/C1_thinF_IMG_20150604_104722_cell_164.png',
#  './cell_images/Uninfected/C5NThinF_IMG_20150609_122108_cell_92.png',
#  './cell_images/Parasitized/C129P90ThinF_IMG_20151004_133703_cell_85.png',
#  './cell_images/Parasitized/C96P57ThinF_IMG_20150824_105213_cell_209.png',
#  './cell_images/Uninfected/C130P91ThinF_IMG_20151004_142951_cell_25.png',
#  './cell_images/Uninfected/C169P130ThinF_IMG_20151119_143039_cell_13.png',
#  './cell_images/Parasitized/C99P60ThinF_IMG_20150918_141620_cell_53.png',
#  './cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_236.png',
#  './cell_images/Uninfected/C62P23N_ThinF_IMG_20150818_133211_cell_169.png',
#  './cell_images/Uninfected/C185P146ThinF_IMG_20151203_111121_cell_176.png',
#  './cell_images/Parasitized/C133P94ThinF_IMG_20151004_154512_cell_140.png',
#  './cell_images/Uninfected/C116P77ThinF_IMG_20150930_171635_cell_31.png',
#  './cell_images/Uninfected/C140P101ThinF_IMG_20151005_210026_cell_68.png',
#  './cell_images/Uninfected/C52P13thinF_IMG_20150725_124830_cell_15.png',
#  './cell_images/Uninfected/C184P145ThinF_IMG_20151203_103824_cell_41.png',
#  './cell_images/Parasitized/C39P4thinF_original_IMG_20150622_113842_cell_40.png',
#  './cell_images/Parasitized/C48P9thinF_IMG_20150721_164304_cell_27.png',
#  './cell_images/Parasitized/C116P77ThinF_IMG_20150930_171954_cell_102.png',
#  './cell_images/Parasitized/C82P43ThinF_IMG_20150817_124010_cell_208.png',
#  './cell_images/Uninfected/C90P51ThinF_IMG_20150821_115310_cell_120.png',
#  './cell_images/Uninfected/C186P147NThinF_IMG_20151203_150222_cell_54.png',
#  './cell_images/Uninfected/C170P131ThinF_IMG_20151119_120019_cell_130.png',
#  './cell_images/Parasitized/C158P119ThinF_IMG_20151115_181136_cell_196.png',
#  './cell_images/Uninfected/C85P46ThinF_IMG_20150820_110040_cell_182.png',
#  './cell_images/Parasitized/C136P97ThinF_IMG_20151005_143329_cell_108.png',
#  './cell_images/Uninfected/C238NThinF_IMG_20151207_114038_cell_192.png',
#  './cell_images/Uninfected/C78P39ThinF_IMG_20150606_104426_cell_54.png',
#  './cell_images/Uninfected/C124P85ThinF_IMG_20151002_155101_cell_90.png',
#  './cell_images/Uninfected/C117P78ThinF_IMG_20150930_214317_cell_20.png',
#  './cell_images/Uninfected/C97P58ThinF_IMG_20150917_152032_cell_101.png',
#  './cell_images/Parasitized/C80P41ThinF_IMG_20150817_111121_cell_149.png',
#  './cell_images/Parasitized/C184P145ThinF_IMG_20151203_103114_cell_149.png',
#  './cell_images/Uninfected/C148P109ThinF_IMG_20151115_112855_cell_87.png',
#  './cell_images/Uninfected/C57P18thinF_IMG_20150729_111518_cell_232.png',
#  './cell_images/Parasitized/C189P150ThinF_IMG_20151203_141308_cell_66.png',
#  './cell_images/Uninfected/C126P87ThinF_IMG_20151004_104813_cell_6.png',
#  './cell_images/Parasitized/C99P60ThinF_IMG_20150918_142128_cell_79.png',
#  './cell_images/Parasitized/C118P79ThinF_IMG_20151002_110725_cell_139.png',
#  './cell_images/Uninfected/C78P39ThinF_IMG_20150606_104426_cell_24.png',
#  './cell_images/Uninfected/C12NThinF_IMG_20150614_125703_cell_187.png',
#  './cell_images/Parasitized/C92P53ThinF_IMG_20150821_151722_cell_223.png',
#  './cell_images/Parasitized/C105P66ThinF_IMG_20150924_095913_cell_118.png',
#  './cell_images/Parasitized/C132P93ThinF_IMG_20151004_151733_cell_152.png',
#  './cell_images/Uninfected/C106P67ThinF_IMG_20150924_102826_cell_140.png',
#  './cell_images/Uninfected/C128P89ThinF_IMG_20151004_130810_cell_81.png',
#  './cell_images/Uninfected/C62P23N_ThinF_IMG_20150818_133055_cell_59.png',
#  './cell_images/Parasitized/C132P93ThinF_IMG_20151004_151701_cell_131.png',
#  './cell_images/Parasitized/C89P50ThinF_IMG_20150820_162504_cell_193.png',
#  './cell_images/Parasitized/C68P29N_ThinF_IMG_20150819_134712_cell_55.png',
#  './cell_images/Parasitized/C184P145ThinF_IMG_20151203_102543_cell_167.png',
#  './cell_images/Parasitized/C137P98ThinF_IMG_20151005_161859_cell_84.png',
#  './cell_images/Parasitized/C175P136NThinF_IMG_20151127_142326_cell_225.png',
#  './cell_images/Parasitized/C118P79ThinF_IMG_20151002_105827_cell_134.png',
#  './cell_images/Parasitized/C166P127ThinF_IMG_20151117_194147_cell_220.png',
#  './cell_images/Parasitized/C33P1thinF_IMG_20150619_121411a_cell_189.png',
#  './cell_images/Parasitized/C39P4thinF_original_IMG_20150622_111723_cell_82.png',
#  './cell_images/Uninfected/C218ThinF_IMG_20151106_144143_cell_142.png',
#  './cell_images/Parasitized/C189P150ThinF_IMG_20151203_140809_cell_129.png',
#  './cell_images/Uninfected/C185P146ThinF_IMG_20151203_110817_cell_98.png',
#  './cell_images/Uninfected/C207ThinF_IMG_20151029_144152_cell_170.png',
#  './cell_images/Uninfected/C116P77ThinF_IMG_20150930_171219_cell_21.png',
#  './cell_images/Parasitized/C132P93ThinF_IMG_20151004_152257_cell_148.png',
#  './cell_images/Uninfected/C90P51ThinF_IMG_20150821_115700_cell_89.png',
#  './cell_images/Parasitized/C48P9thinF_IMG_20150721_164129_cell_16.png',
#  './cell_images/Parasitized/C137P98ThinF_IMG_20151005_162010_cell_84.png',
#  './cell_images/Parasitized/C182P143NThinF_IMG_20151201_171836_cell_181.png',
#  './cell_images/Uninfected/C12NThinF_IMG_20150614_125741_cell_175.png',
#  './cell_images/Parasitized/C39P4thinF_original_IMG_20150622_113632_cell_23.png',
#  './cell_images/Parasitized/C187P148NThinF_IMG_20151203_153713_cell_195.png',
#  './cell_images/Uninfected/C102P63ThinF_IMG_20150918_162051_cell_1.png',
#  './cell_images/Uninfected/C79P40ThinF_IMG_20150817_104745_cell_23.png',
#  './cell_images/Uninfected/C57P18thinF_IMG_20150729_110134_cell_52.png',
#  './cell_images/Parasitized/C132P93ThinF_IMG_20151004_152505_cell_133.png',
#  './cell_images/Parasitized/C144P105ThinF_IMG_20151015_155004_cell_298.png',
#  './cell_images/Uninfected/C95P56ThinF_IMG_20150821_171530_cell_4.png',
#  './cell_images/Uninfected/C51AP12thinF_IMG_20150724_154243_cell_32.png',
#  './cell_images/Uninfected/C227ThinF_IMG_20151112_135422_cell_51.png',
#  './cell_images/Parasitized/C182P143NThinF_IMG_20151201_172216_cell_201.png',
#  './cell_images/Uninfected/C91P52ThinF_IMG_20150821_124937_cell_5.png',
#  './cell_images/Uninfected/C163P124ThinF_IMG_20151116_111925_cell_25.png',
#  './cell_images/Uninfected/C209ThinF_IMG_20151029_160857_cell_145.png',
#  './cell_images/Uninfected/C171P132ThinF_IMG_20151119_153512_cell_172.png',
#  './cell_images/Uninfected/C111P72ThinF_IMG_20150930_113210_cell_164.png',
#  './cell_images/Parasitized/C116P77ThinF_IMG_20150930_171739_cell_90.png',
#  './cell_images/Uninfected/C147P108ThinF_IMG_20151115_103432_cell_117.png',
#  './cell_images/Uninfected/C60P21thinF_IMG_20150804_105034_cell_49.png',
#  './cell_images/Uninfected/C145P106ThinF_IMG_20151016_154844_cell_36.png',
#  './cell_images/Uninfected/C73P34_ThinF_IMG_20150815_112246_cell_12.png',
#  './cell_images/Parasitized/C184P145ThinF_IMG_20151203_104153_cell_137.png',
#  './cell_images/Parasitized/C51AP12thinF_IMG_20150724_153313_cell_105.png',
#  './cell_images/Uninfected/C72P33_ThinF_IMG_20150815_104045_cell_50.png',
#  './cell_images/Parasitized/C172P133ThinF_IMG_20151119_155343_cell_286.png',
#  './cell_images/Parasitized/C137P98ThinF_IMG_20151005_161449_cell_8.png',
#  './cell_images/Uninfected/C142P103ThinF_IMG_20151005_222255_cell_17.png',
#  './cell_images/Parasitized/C141P102ThinF_IMG_20151005_214836_cell_148.png',
#  './cell_images/Parasitized/C128P89ThinF_IMG_20151004_131231_cell_154.png',
#  './cell_images/Parasitized/C68P29N_ThinF_IMG_20150819_133236_cell_167.png',
#  './cell_images/Uninfected/C99P60ThinF_IMG_20150918_141129_cell_77.png',
#  './cell_images/Parasitized/C84P45ThinF_IMG_20150818_104849_cell_19.png',
#  './cell_images/Uninfected/C221ThinF_IMG_20151106_160304_cell_212.png',
#  './cell_images/Uninfected/C90P51ThinF_IMG_20150821_115700_cell_98.png',
#  './cell_images/Parasitized/C180P141NThinF_IMG_20151201_163702_cell_197.png',
#  './cell_images/Parasitized/C39P4thinF_original_IMG_20150622_105102_cell_94.png',
#  './cell_images/Uninfected/C73P34_ThinF_IMG_20150815_111302_cell_19.png',
#  './cell_images/Uninfected/C211ThinF_IMG_20151029_164218_cell_20.png',
#  './cell_images/Uninfected/C149P110ThinF_IMG_20151115_114629_cell_28.png',
#  './cell_images/Parasitized/C45P6ThinF_IMG_20151130_160135_cell_206.png',
#  './cell_images/Parasitized/C124P85ThinF_IMG_20151002_155223_cell_168.png',
#  './cell_images/Uninfected/C177P138NThinF_IMG_20151201_141604_cell_18.png',
#  './cell_images/Parasitized/C182P143NThinF_IMG_20151201_172216_cell_129.png',
#  './cell_images/Parasitized/C66P27N_ThinF_IMG_20150818_164008_cell_162.png',
#  './cell_images/Parasitized/C189P150ThinF_IMG_20151203_140902_cell_125.png',
#  './cell_images/Uninfected/C13NThinF_IMG_20150614_131417_cell_18.png',
#  './cell_images/Parasitized/C118P79ThinF_IMG_20151002_110725_cell_138.png',
#  './cell_images/Parasitized/C78P39ThinF_IMG_20150606_103413_cell_169.png',
#  './cell_images/Parasitized/C91P52ThinF_IMG_20150821_124311_cell_20.png',
#  './cell_images/Uninfected/C92P53ThinF_IMG_20150821_151646_cell_198.png',
#  './cell_images/Parasitized/C129P90ThinF_IMG_20151004_134700_cell_27.png',
#  './cell_images/Uninfected/C233ThinF_IMG_20151112_160059_cell_17.png',
#  './cell_images/Parasitized/C136P97ThinF_IMG_20151005_144449_cell_7.png',
# ...
#  './cell_images/Uninfected/C96P57ThinF_IMG_20150824_111748_cell_128.png',
#  './cell_images/Uninfected/C153P114ThinF_IMG_20151115_135746_cell_100.png',
#  './cell_images/Parasitized/C60P21thinF_IMG_20150804_105034_cell_111.png',
#  './cell_images/Uninfected/C201ThinF_IMG_20150930_143502_cell_186.png',
#  './cell_images/Uninfected/C156P117ThinF_IMG_20151115_154435_cell_192.png',
#  './cell_images/Parasitized/C70P31_ThinF_IMG_20150813_131457_cell_16.png',
#  './cell_images/Uninfected/C98P59ThinF_IMG_20150917_154235_cell_143.png',
#  './cell_images/Uninfected/C181P142ThinF_IMG_20151127_160539_cell_42.png',
#  './cell_images/Uninfected/C160P121ThinF_IMG_20151116_094509_cell_98.png',
#  './cell_images/Parasitized/C99P60ThinF_IMG_20150918_140900_cell_121.png',
#  './cell_images/Parasitized/C129P90ThinF_IMG_20151004_134700_cell_14.png',
#  './cell_images/Uninfected/C172P133ThinF_IMG_20151119_155156_cell_165.png',
#  './cell_images/Parasitized/C132P93ThinF_IMG_20151004_151941_cell_29.png',
#  './cell_images/Parasitized/C68P29N_ThinF_IMG_20150819_133447_cell_178.png',
#  './cell_images/Uninfected/C104P65ThinF_IMG_20150918_171154_cell_88.png',
#  './cell_images/Parasitized/C176P137NThinF_IMG_20151201_120845_cell_133.png',
#  './cell_images/Uninfected/C2NThinF_IMG_20150604_114751_cell_106.png',
#  './cell_images/Parasitized/C184P145ThinF_IMG_20151203_104334_cell_14.png',
#  './cell_images/Parasitized/C102P63ThinF_IMG_20150918_162927_cell_4.png',
#  './cell_images/Uninfected/C221ThinF_IMG_20151106_155857_cell_97.png',
#  './cell_images/Parasitized/C39P4thinF_original_IMG_20150622_113632_cell_20.png',
#  './cell_images/Uninfected/C94P55ThinF_IMG_20150821_165118_cell_237.png',
#  './cell_images/Parasitized/C129P90ThinF_IMG_20151004_133703_cell_106.png',
#  './cell_images/Parasitized/C59P20thinF_IMG_20150803_112733_cell_220.png',
#  './cell_images/Uninfected/C121P82ThinF_IMG_20151002_133540_cell_78.png',
#  './cell_images/Uninfected/C110P71ThinF_IMG_20150930_105729_cell_18.png',
#  './cell_images/Parasitized/C136P97ThinF_IMG_20151005_141946_cell_98.png',
#  './cell_images/Parasitized/C129P90ThinF_IMG_20151004_134944_cell_25.png',
#  './cell_images/Uninfected/C86P47ThinF_IMG_20150820_124259_cell_189.png',
#  './cell_images/Parasitized/C184P145ThinF_IMG_20151203_102405_cell_166.png',
#  './cell_images/Parasitized/C39P4thinF_original_IMG_20150622_114804_cell_2.png',
#  './cell_images/Parasitized/C136P97ThinF_IMG_20151005_144449_cell_10.png',
#  './cell_images/Uninfected/C104P65ThinF_IMG_20150918_171154_cell_4.png',
#  './cell_images/Parasitized/C174P135NThinF_IMG_20151127_135435_cell_208.png',
#  './cell_images/Parasitized/C59P20thinF_IMG_20150803_112733_cell_210.png',
#  './cell_images/Uninfected/C105P66ThinF_IMG_20150924_094944_cell_3.png',
#  './cell_images/Uninfected/C139P100ThinF_IMG_20151005_182822_cell_36.png',
#  './cell_images/Uninfected/C204ThinF_IMG_20151029_110834_cell_278.png',
#  './cell_images/Parasitized/C118P79ThinF_IMG_20151002_105346_cell_156.png',
#  './cell_images/Parasitized/C129P90ThinF_IMG_20151004_133921_cell_113.png',
#  './cell_images/Uninfected/C63P24N_ThinF_IMG_20150818_143319_cell_75.png',
#  './cell_images/Uninfected/C84P45ThinF_IMG_20150818_101146_cell_45.png',
#  './cell_images/Uninfected/C151P112ThinF_IMG_20151115_121725_cell_70.png',
#  './cell_images/Uninfected/C135P96ThinF_IMG_20151005_124359_cell_113.png',
#  './cell_images/Parasitized/C99P60ThinF_IMG_20150918_140900_cell_133.png',
#  './cell_images/Parasitized/C99P60ThinF_IMG_20150918_141620_cell_8.png',
#  './cell_images/Parasitized/C184P145ThinF_IMG_20151203_103637_cell_154.png',
#  './cell_images/Parasitized/C176P137NThinF_IMG_20151201_122444_cell_127.png',
#  './cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_12.png',
#  './cell_images/Parasitized/C80P41ThinF_IMG_20150817_111246_cell_127.png',
#  './cell_images/Uninfected/C167P128ReThinF_IMG_20151201_105707_cell_66.png',
#  './cell_images/Uninfected/C218ThinF_IMG_20151106_144001_cell_133.png',
#  './cell_images/Uninfected/C148P109ThinF_IMG_20151115_112538_cell_142.png',
#  './cell_images/Uninfected/C241NThinF_IMG_20151207_124240_cell_6.png',
#  './cell_images/Parasitized/C183P144NThinF_IMG_20151201_223758_cell_128.png',
#  './cell_images/Uninfected/C135P96ThinF_IMG_20151005_123857_cell_79.png',
#  './cell_images/Parasitized/C107P68ThinF_IMG_20150924_222233_cell_161.png',
#  './cell_images/Uninfected/C184P145ThinF_IMG_20151203_103637_cell_28.png',
#  './cell_images/Parasitized/C132P93ThinF_IMG_20151004_151701_cell_166.png',
#  './cell_images/Uninfected/C81P42ThinF_IMG_20150817_121113_cell_34.png',
#  './cell_images/Parasitized/C132P93ThinF_IMG_20151004_152642_cell_35.png',
#  './cell_images/Parasitized/C184P145ThinF_IMG_20151203_102405_cell_173.png',
#  './cell_images/Parasitized/C184P145ThinF_IMG_20151203_102721_cell_19.png',
#  './cell_images/Uninfected/C227ThinF_IMG_20151112_135422_cell_54.png',
#  './cell_images/Uninfected/C149P110ThinF_IMG_20151115_114555_cell_259.png',
#  './cell_images/Parasitized/C129P90ThinF_IMG_20151004_134944_cell_11.png',
#  './cell_images/Uninfected/C134P95ThinF_IMG_20151005_121952_cell_91.png',
#  './cell_images/Uninfected/C52P13thinF_IMG_20150725_124830_cell_86.png',
#  './cell_images/Parasitized/C39P4thinF_original_IMG_20150622_105554_cell_23.png',
#  './cell_images/Uninfected/C105P66ThinF_IMG_20150924_095716_cell_98.png',
#  './cell_images/Uninfected/C51AP12thinF_IMG_20150724_155557_cell_9.png',
#  './cell_images/Uninfected/C228ThinF_IMG_20151112_142216_cell_59.png',
#  './cell_images/Uninfected/C123P84ThinF_IMG_20151002_151143_cell_148.png',
#  './cell_images/Parasitized/C118P79ThinF_IMG_20151002_110725_cell_152.png',
#  './cell_images/Uninfected/C208ThinF_IMG_20151029_151017_cell_210.png',
#  './cell_images/Parasitized/C51AP12thinF_IMG_20150724_160140_cell_67.png',
#  './cell_images/Uninfected/C5NThinF_IMG_20150609_122020_cell_48.png',
#  './cell_images/Parasitized/C181P142ThinF_IMG_20151127_160650_cell_171.png',
#  './cell_images/Parasitized/C84P45ThinF_IMG_20150818_102654_cell_79.png',
#  './cell_images/Uninfected/C201ThinF_IMG_20150930_143129_cell_130.png',
#  './cell_images/Parasitized/C48P9thinF_IMG_20150721_164031_cell_7.png',
#  './cell_images/Uninfected/C136P97ThinF_IMG_20151005_142437_cell_7.png',
#  './cell_images/Uninfected/C108P69ThinF_IMG_20150924_225511_cell_128.png',
#  './cell_images/Parasitized/C118P79ThinF_IMG_20151002_105125_cell_145.png',
#  './cell_images/Uninfected/C62P23N_ThinF_IMG_20150818_133307_cell_129.png',
#  './cell_images/Parasitized/C68P29N_ThinF_IMG_20150819_134112_cell_158.png',
#  './cell_images/Parasitized/C128P89ThinF_IMG_20151004_131753_cell_126.png',
#  './cell_images/Uninfected/C153P114ThinF_IMG_20151115_135639_cell_238.png',
#  './cell_images/Parasitized/C63P24N_ThinF_IMG_20150818_143423_cell_163.png',
#  './cell_images/Uninfected/C96P57ThinF_IMG_20150824_105531_cell_207.png',
#  './cell_images/Parasitized/C51AP12thinF_IMG_20150724_160140_cell_62.png',
#  './cell_images/Parasitized/C91P52ThinF_IMG_20150821_125423_cell_17.png',
#  './cell_images/Parasitized/C175P136NThinF_IMG_20151127_141428_cell_218.png',
#  './cell_images/Parasitized/C167P128ReThinF_IMG_20151201_105707_cell_235.png',
#  './cell_images/Uninfected/C143P104ThinF_IMG_20151005_225454_cell_17.png',
#  './cell_images/Uninfected/C91P52ThinF_IMG_20150821_124504_cell_32.png',
#  './cell_images/Parasitized/C39P4thinF_original_IMG_20150622_113842_cell_2.png',
#  './cell_images/Uninfected/C186P147NThinF_IMG_20151203_150408_cell_56.png',
#  './cell_images/Parasitized/C147P108ThinF_IMG_20151115_101317_cell_193.png',
#  './cell_images/Uninfected/C70P31_ThinF_IMG_20150819_142744_cell_1.png',
#  './cell_images/Uninfected/C230ThinF_IMG_20151112_150329_cell_31.png',
#  './cell_images/Uninfected/C2NThinF_IMG_20150604_114751_cell_221.png',
#  './cell_images/Uninfected/C117P78ThinF_IMG_20150930_214629_cell_77.png',
#  './cell_images/Uninfected/C182P143NThinF_IMG_20151201_172257_cell_15.png',
#  './cell_images/Uninfected/C101P62ThinF_IMG_20150918_151507_cell_15.png',
#  './cell_images/Uninfected/C55P16thinF_IMG_20150728_123510_cell_2.png',
#  './cell_images/Uninfected/C86P47ThinF_IMG_20150820_123717_cell_170.png',
#  './cell_images/Uninfected/C47P8thinOriginalOlympusCX21_IMG_20150717_173515_cell_10.png',
#  './cell_images/Parasitized/C172P133ThinF_IMG_20151119_155019_cell_236.png',
#  './cell_images/Parasitized/C99P60ThinF_IMG_20150918_141520_cell_143.png',
#  './cell_images/Parasitized/C119P80ThinF_IMG_20151002_122720_cell_161.png',
#  './cell_images/Uninfected/C189P150ThinF_IMG_20151203_141406_cell_47.png',
#  './cell_images/Parasitized/C98P59ThinF_IMG_20150917_154235_cell_207.png',
#  './cell_images/Parasitized/C80P41ThinF_IMG_20150817_110608_cell_156.png',
#  './cell_images/Parasitized/C48P9thinF_IMG_20150721_160944_cell_204.png',
#  './cell_images/Parasitized/C59P20thinF_IMG_20150803_113139_cell_56.png',
#  './cell_images/Uninfected/C93P54ThinF_IMG_20150821_164024_cell_133.png',
#  './cell_images/Uninfected/C100P61ThinF_IMG_20150918_145042_cell_7.png',
#  './cell_images/Uninfected/C144P105ThinF_IMG_20151015_155004_cell_129.png',
#  './cell_images/Parasitized/C68P29N_ThinF_IMG_20150819_134712_cell_73.png',
#  './cell_images/Uninfected/C154P115ThinF_IMG_20151115_141507_cell_166.png',
#  './cell_images/Parasitized/C132P93ThinF_IMG_20151004_151733_cell_184.png',
#  './cell_images/Parasitized/C186P147NThinF_IMG_20151203_150557_cell_191.png',
#  './cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133111a_cell_40.png',
#  './cell_images/Uninfected/C231ThinF_IMG_20151112_152234_cell_176.png',
#  './cell_images/Uninfected/C162P123ThinF_IMG_20151116_104736_cell_30.png',
#  './cell_images/Parasitized/C91P52ThinF_IMG_20150821_123314_cell_200.png',
#  './cell_images/Uninfected/C171P132ThinF_IMG_20151119_153851_cell_170.png',
#  './cell_images/Parasitized/C97P58ThinF_IMG_20150917_152437_cell_8.png',
#  './cell_images/Uninfected/C138P99ThinF_IMG_20151005_173241_cell_119.png',
#  './cell_images/Parasitized/C84P45ThinF_IMG_20150818_102654_cell_77.png',
#  './cell_images/Parasitized/C79P40ThinF_IMG_20150817_104919_cell_132.png',
#  './cell_images/Parasitized/C101P62ThinF_IMG_20150918_151942_cell_87.png',
#  './cell_images/Uninfected/C112P73ThinF_IMG_20150930_131516_cell_109.png',
#  './cell_images/Uninfected/C90P51ThinF_IMG_20150821_115846_cell_65.png',
#  './cell_images/Parasitized/C180P141NThinF_IMG_20151201_164714_cell_171.png',
#  './cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_88.png',
#  './cell_images/Uninfected/C108P69ThinF_IMG_20150924_223834_cell_195.png',
#  './cell_images/Parasitized/C133P94ThinF_IMG_20151004_153930_cell_99.png',
#  './cell_images/Parasitized/C146P107ThinF_IMG_20151018_140044_cell_218.png',
#  './cell_images/Uninfected/C210ThinF_IMG_20151029_162357_cell_150.png',
#  './cell_images/Uninfected/C80P41ThinF_IMG_20150817_110348_cell_66.png',
#  './cell_images/Uninfected/C221ThinF_IMG_20151106_155857_cell_85.png',
#  './cell_images/Parasitized/C174P135NThinF_IMG_20151127_135554_cell_191.png',
#  './cell_images/Parasitized/C182P143NThinF_IMG_20151201_172842_cell_47.png',
#  './cell_images/Parasitized/C186P147NThinF_IMG_20151203_150808_cell_137.png',
#  './cell_images/Parasitized/C116P77ThinF_IMG_20150930_171954_cell_96.png',
#  './cell_images/Uninfected/C211ThinF_IMG_20151029_164218_cell_112.png',
#  './cell_images/Parasitized/C176P137NThinF_IMG_20151201_121808_cell_123.png',
#  './cell_images/Parasitized/C132P93ThinF_IMG_20151004_151941_cell_35.png',
#  './cell_images/Uninfected/C160P121ThinF_IMG_20151116_093748_cell_101.png',
#  './cell_images/Uninfected/C114P75ThinF_IMG_20150930_150013_cell_117.png',
#  './cell_images/Uninfected/C176P137NThinF_IMG_20151201_114035_cell_115.png',
#  './cell_images/Parasitized/C108P69ThinF_IMG_20150924_224038_cell_190.png',
#  './cell_images/Parasitized/C189P150ThinF_IMG_20151203_140809_cell_130.png',
#  './cell_images/Uninfected/C240ThinF_IMG_20151127_115328_cell_16.png',
#  './cell_images/Uninfected/C207ThinF_IMG_20151029_144152_cell_115.png',
#  './cell_images/Parasitized/C186P147NThinF_IMG_20151203_150322_cell_164.png',
#  './cell_images/Uninfected/C56P17thinF_IMG_20150728_153328_cell_72.png',
#  './cell_images/Parasitized/C80P41ThinF_IMG_20150817_111802_cell_23.png',
#  './cell_images/Uninfected/C207ThinF_IMG_20151029_144152_cell_205.png',
#  './cell_images/Uninfected/C95P56ThinF_IMG_20150821_172351_cell_13.png',
#  './cell_images/Uninfected/C206ThinF_IMG_20151029_141047_cell_84.png',
#  './cell_images/Parasitized/C76P37ThinF_IMG_20150815_173019_cell_237.png',
#  './cell_images/Uninfected/C90P51ThinF_IMG_20150821_115056_cell_119.png',
#  './cell_images/Uninfected/C104P65ThinF_IMG_20150918_172537_cell_133.png',
#  './cell_images/Parasitized/C132P93ThinF_IMG_20151004_151811_cell_150.png',
#  './cell_images/Parasitized/C101P62ThinF_IMG_20150923_165215_cell_16.png',
#  './cell_images/Uninfected/C211ThinF_IMG_20151029_164248_cell_80.png',
#  './cell_images/Uninfected/C119P80ThinF_IMG_20151002_123911_cell_54.png',
#  './cell_images/Parasitized/C51AP12thinF_IMG_20150724_155046_cell_91.png',
#  './cell_images/Parasitized/C59P20thinF_IMG_20150803_113809_cell_49.png',
#  './cell_images/Uninfected/C187P148NThinF_IMG_20151203_154503_cell_40.png',
#  './cell_images/Parasitized/C179P140ThinF_IMG_20151127_153350_cell_170.png',
#  './cell_images/Parasitized/C81P42ThinF_IMG_20150817_120524_cell_184.png',
#  './cell_images/Parasitized/C132P93ThinF_IMG_20151004_153030_cell_18.png',
#  './cell_images/Uninfected/C121P82ThinF_IMG_20151002_133631_cell_52.png',
#  './cell_images/Uninfected/C101P62ThinF_IMG_20150918_151507_cell_21.png',
#  './cell_images/Uninfected/C215ThinF_IMG_20151106_133043_cell_92.png',
#  './cell_images/Parasitized/C91P52ThinF_IMG_20150821_124311_cell_2.png',
#  './cell_images/Parasitized/C183P144NThinF_IMG_20151201_222917_cell_160.png',
#  './cell_images/Parasitized/C76P37ThinF_IMG_20150815_172902_cell_221.png',
#  './cell_images/Uninfected/C54P15thinF_IMG_20150728_113006_cell_197.png',
#  './cell_images/Parasitized/C184P145ThinF_IMG_20151203_103114_cell_177.png',
#  './cell_images/Parasitized/C184P145ThinF_IMG_20151203_102543_cell_164.png',
#  './cell_images/Parasitized/C101P62ThinF_IMG_20150918_151335_cell_58.png',
#  './cell_images/Uninfected/C211ThinF_IMG_20151029_164248_cell_43.png',
#  './cell_images/Uninfected/C229ThinF_IMG_20151112_144613_cell_99.png',
#  './cell_images/Uninfected/C68P29N_ThinF_IMG_20150819_133236_cell_57.png',
#  './cell_images/Parasitized/C39P4thinF_original_IMG_20150622_111326_cell_1.png',
#  './cell_images/Uninfected/C86P47ThinF_IMG_20150820_125057_cell_73.png',
#  './cell_images/Uninfected/C84P45ThinF_IMG_20150818_101146_cell_76.png',
#  './cell_images/Parasitized/C183P144NThinF_IMG_20151201_223758_cell_143.png',
#  './cell_images/Uninfected/C168P129ThinF_IMG_20151118_154651_cell_112.png',
#  './cell_images/Parasitized/C99P60ThinF_IMG_20150918_141001_cell_114.png',
#  './cell_images/Uninfected/C214ThinF_IMG_20151106_114910_cell_185.png',
#  './cell_images/Uninfected/C240ThinF_IMG_20151127_115545_cell_174.png',
#  './cell_images/Parasitized/C84P45ThinF_IMG_20150818_102325_cell_100.png',
#  './cell_images/Parasitized/C97P58ThinF_IMG_20150917_151903_cell_13.png',
#  './cell_images/Uninfected/C180P141NThinF_IMG_20151201_163751_cell_95.png',
#  './cell_images/Uninfected/C219ThinF_IMG_20151106_145856_cell_170.png',
#  './cell_images/Parasitized/C146P107ThinF_IMG_20151018_140439_cell_283.png',
#  './cell_images/Parasitized/C101P62ThinF_IMG_20150918_151942_cell_79.png',
#  './cell_images/Parasitized/C139P100ThinF_IMG_20151005_183601_cell_152.png',
#  './cell_images/Parasitized/C137P98ThinF_IMG_20151005_163218_cell_84.png',
#  './cell_images/Uninfected/C45P6ThinF_IMG_20151130_155110_cell_161.png',
#  './cell_images/Uninfected/C71P32_ThinF_IMG_20150813_163120_cell_70.png',
#  './cell_images/Uninfected/C42P5thin_original_IMG_20150623_134751_cell_107.png',
#  ...]
# ThreadPoolExecutor-0_0: working on img num: 0
# ThreadPoolExecutor-0_0: working on img num: 5000
# ThreadPoolExecutor-0_4: working on img num: 10000
# ThreadPoolExecutor-0_5: working on img num: 15000
# ThreadPoolExecutor-0_5: working on img num: 17360
# Min Dimensions: [40 46  3]
# Avg Dimensions: [132.94470365 132.47226542   3.        ]
# Median Dimensions: [130. 130.   3.]
# Max Dimensions: [382 394   3]

# %%
IMG_DIMS = (125, 125)

def get_img_data_parallel(idx, img, total_imgs):
    if idx % 5000 == 0 or idx == (total_imgs - 1):
        print('{}: working on img num: {}'.format(threading.current_thread().name,
                                                  idx))
    img = cv2.imread(img)
    img = cv2.resize(img, dsize=IMG_DIMS,
                     interpolation=cv2.INTER_CUBIC)
    img = np.array(img, dtype=np.float32)
    return img

ex = futures.ThreadPoolExecutor(max_workers=None)
train_data_inp = [(idx, img, len(train_files)) for idx, img in enumerate(train_files)]
val_data_inp = [(idx, img, len(val_files)) for idx, img in enumerate(val_files)]
test_data_inp = [(idx, img, len(test_files)) for idx, img in enumerate(test_files)]

print('Loading Train Images:')
train_data_map = ex.map(get_img_data_parallel,
                        [record[0] for record in train_data_inp],
                        [record[1] for record in train_data_inp],
                        [record[2] for record in train_data_inp])
train_data = np.array(list(train_data_map))

print('\nLoading Validation Images:')
val_data_map = ex.map(get_img_data_parallel,
                        [record[0] for record in val_data_inp],
                        [record[1] for record in val_data_inp],
                        [record[2] for record in val_data_inp])
val_data = np.array(list(val_data_map))

print('\nLoading Test Images:')
test_data_map = ex.map(get_img_data_parallel,
                        [record[0] for record in test_data_inp],
                        [record[1] for record in test_data_inp],
                        [record[2] for record in test_data_inp])
test_data = np.array(list(test_data_map))

train_data.shape, val_data.shape, test_data.shape
# Out:
# Loading Train Images:
# ThreadPoolExecutor-1_0: working on img num: 0
# ThreadPoolExecutor-1_5: working on img num: 5000
# ThreadPoolExecutor-1_6: working on img num: 10000
# ThreadPoolExecutor-1_2: working on img num: 15000
# ThreadPoolExecutor-1_1: working on img num: 17360
#
# Loading Validation Images:
# ThreadPoolExecutor-1_0: working on img num: 0
# ThreadPoolExecutor-1_5: working on img num: 1928
#
# Loading Test Images:
# ThreadPoolExecutor-1_2: working on img num: 0
# ThreadPoolExecutor-1_5: working on img num: 5000
# ThreadPoolExecutor-1_5: working on img num: 8267
# ((17361, 125, 125, 3), (1929, 125, 125, 3), (8268, 125, 125, 3))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(1 , figsize = (8 , 8))
n = 0
for i in range(16):
    n += 1
    r = np.random.randint(0 , train_data.shape[0] , 1)
    plt.subplot(4 , 4 , n)
    plt.subplots_adjust(hspace = 0.5 , wspace = 0.5)
    plt.imshow(train_data[r[0]]/255.)
    plt.title('{}'.format(train_labels[r[0]]))
    plt.xticks([]) , plt.yticks([])

# %%
BATCH_SIZE = 64
NUM_CLASSES = 2
EPOCHS = 25
INPUT_SHAPE = (125, 125, 3)

train_imgs_scaled = train_data / 255.
val_imgs_scaled = val_data / 255.

# encode text category labels
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(train_labels)
train_labels_enc = le.transform(train_labels)
val_labels_enc = le.transform(val_labels)

print(train_labels[:6], train_labels_enc[:6])
# Out:
# ['malaria' 'malaria' 'malaria' 'healthy' 'healthy' 'malaria'] [1 1 1 0 0 1]

# %%
#!pip install tensorflow
import tensorflow as tf

# Load the TensorBoard notebook extension (optional)
#%load_ext tensorboard.notebook

tf.random.set_seed(42)
tf.__version__
# Out:
# '2.3.0'

# %%
inp = tf.keras.layers.Input(shape=INPUT_SHAPE)

conv1 = tf.keras.layers.Conv2D(32, kernel_size=(3, 3),
                               activation='relu', padding='same')(inp)
pool1 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(conv1)
conv2 = tf.keras.layers.Conv2D(64, kernel_size=(3, 3),
                               activation='relu', padding='same')(pool1)
pool2 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(conv2)
conv3 = tf.keras.layers.Conv2D(128, kernel_size=(3, 3),
                               activation='relu', padding='same')(pool2)
pool3 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(conv3)

flat = tf.keras.layers.Flatten()(pool3)

hidden1 = tf.keras.layers.Dense(512, activation='relu')(flat)
drop1 = tf.keras.layers.Dropout(rate=0.3)(hidden1)
hidden2 = tf.keras.layers.Dense(512, activation='relu')(drop1)
drop2 = tf.keras.layers.Dropout(rate=0.3)(hidden2)

out = tf.keras.layers.Dense(1, activation='sigmoid')(drop2)

model = tf.keras.Model(inputs=inp, outputs=out)
model.compile(optimizer='adam',
                loss='binary_crossentropy',
                metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 125, 125, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 125, 125, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 62, 62, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 62, 62, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 31, 31, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 31, 31, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 15, 15, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 28800)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               14746112
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 15,102,529
# Trainable params: 15,102,529
# Non-trainable params: 0
# _________________________________________________________________

# %%
import datetime

logdir = os.path.join('/home/dipanzan_sarkar/projects/tensorboard_logs',
                      datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                              patience=2, min_lr=0.000001)
callbacks = [reduce_lr, tensorboard_callback]

history = model.fit(x=train_imgs_scaled, y=train_labels_enc,
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(val_imgs_scaled, val_labels_enc),
                    callbacks=callbacks,
                    verbose=1)
# Out:
# Epoch 1/25
#   1/272 [..............................] - ETA: 0s - loss: 0.6950 - accuracy: 0.4688WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#   2/272 [..............................] - ETA: 29s - loss: 0.9147 - accuracy: 0.4688WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0532s vs `on_train_batch_end` time: 0.1655s). Check your callbacks.
# 272/272 [==============================] - 26s 97ms/step - loss: 0.3719 - accuracy: 0.8345 - val_loss: 0.2051 - val_accuracy: 0.9393
# Epoch 2/25
# 272/272 [==============================] - 26s 95ms/step - loss: 0.1641 - accuracy: 0.9484 - val_loss: 0.1443 - val_accuracy: 0.9518
# Epoch 3/25
# 272/272 [==============================] - 26s 94ms/step - loss: 0.1317 - accuracy: 0.9580 - val_loss: 0.1404 - val_accuracy: 0.9461
# Epoch 4/25
# 272/272 [==============================] - 26s 95ms/step - loss: 0.1189 - accuracy: 0.9614 - val_loss: 0.1419 - val_accuracy: 0.9533
# Epoch 5/25
# 272/272 [==============================] - 26s 94ms/step - loss: 0.1041 - accuracy: 0.9652 - val_loss: 0.1342 - val_accuracy: 0.9539
# Epoch 6/25
# 272/272 [==============================] - 26s 95ms/step - loss: 0.0858 - accuracy: 0.9706 - val_loss: 0.1550 - val_accuracy: 0.9549
# Epoch 7/25
# 272/272 [==============================] - 26s 95ms/step - loss: 0.0726 - accuracy: 0.9749 - val_loss: 0.1556 - val_accuracy: 0.9476
# Epoch 8/25
# 272/272 [==============================] - 26s 94ms/step - loss: 0.0408 - accuracy: 0.9865 - val_loss: 0.1897 - val_accuracy: 0.9518
# Epoch 9/25
# 272/272 [==============================] - 26s 94ms/step - loss: 0.0255 - accuracy: 0.9915 - val_loss: 0.2320 - val_accuracy: 0.9487
# Epoch 10/25
# 272/272 [==============================] - 26s 95ms/step - loss: 0.0143 - accuracy: 0.9953 - val_loss: 0.2676 - val_accuracy: 0.9513
# Epoch 11/25
# 272/272 [==============================] - 26s 95ms/step - loss: 0.0086 - accuracy: 0.9975 - val_loss: 0.3042 - val_accuracy: 0.9518
# Epoch 12/25
# 272/272 [==============================] - 26s 95ms/step - loss: 0.0052 - accuracy: 0.9988 - val_loss: 0.3340 - val_accuracy: 0.9508
# Epoch 13/25
# 272/272 [==============================] - 26s 95ms/step - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.3361 - val_accuracy: 0.9492
# Epoch 14/25
# 272/272 [==============================] - 26s 95ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.3401 - val_accuracy: 0.9482
# Epoch 15/25
# 272/272 [==============================] - 26s 95ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.3511 - val_accuracy: 0.9502
# Epoch 16/25
# 272/272 [==============================] - 26s 94ms/step - loss: 0.0024 - accuracy: 0.9996 - val_loss: 0.3550 - val_accuracy: 0.9497
# Epoch 17/25
# 272/272 [==============================] - 26s 94ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.3696 - val_accuracy: 0.9492
# Epoch 18/25
# 272/272 [==============================] - 26s 94ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.3656 - val_accuracy: 0.9487
# Epoch 19/25
# 272/272 [==============================] - 26s 95ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.3703 - val_accuracy: 0.9476
# Epoch 20/25
# 272/272 [==============================] - 26s 94ms/step - loss: 0.0018 - accuracy: 0.9998 - val_loss: 0.3715 - val_accuracy: 0.9492
# Epoch 21/25
# 272/272 [==============================] - 26s 95ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.3734 - val_accuracy: 0.9482
# Epoch 22/25
# 272/272 [==============================] - 26s 95ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.3741 - val_accuracy: 0.9487
# Epoch 23/25
# 272/272 [==============================] - 26s 94ms/step - loss: 0.0014 - accuracy: 0.9999 - val_loss: 0.3757 - val_accuracy: 0.9492
# Epoch 24/25
# 272/272 [==============================] - 26s 94ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.3745 - val_accuracy: 0.9492
# Epoch 25/25
# 272/272 [==============================] - 26s 94ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.3748 - val_accuracy: 0.9487

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Basic CNN Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

max_epoch = len(history.history['accuracy'])+1
epoch_list = list(range(1,max_epoch))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(1, max_epoch, 5))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(1, max_epoch, 5))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
vgg = tf.keras.applications.vgg19.VGG19(include_top=False, weights='imagenet',
                                        input_shape=INPUT_SHAPE)
vgg.trainable = False
# Freeze the layers
for layer in vgg.layers:
    layer.trainable = False
   
base_vgg = vgg
base_out = base_vgg.output
pool_out = tf.keras.layers.Flatten()(base_out)
hidden1 = tf.keras.layers.Dense(512, activation='relu')(pool_out)
drop1 = tf.keras.layers.Dropout(rate=0.3)(hidden1)
hidden2 = tf.keras.layers.Dense(512, activation='relu')(drop1)
drop2 = tf.keras.layers.Dropout(rate=0.3)(hidden2)

out = tf.keras.layers.Dense(1, activation='sigmoid')(drop2)

model = tf.keras.Model(inputs=base_vgg.input, outputs=out)
model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=1e-4),
                loss='binary_crossentropy',
                metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 2s 0us/step
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 125, 125, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 125, 125, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 125, 125, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 62, 62, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 62, 62, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 62, 62, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 31, 31, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 31, 31, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 31, 31, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 31, 31, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 31, 31, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 15, 15, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 15, 15, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 15, 15, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 15, 15, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 15, 15, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 7, 7, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 7, 7, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 7, 7, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 7, 7, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               2359808
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 22,647,361
# Trainable params: 2,622,977
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
print("Total Layers:", len(model.layers))
print("Total trainable layers:",
      sum([1 for l in model.layers if l.trainable]))
# Out:
# Total Layers: 28
# Total trainable layers: 6

# %%
model.save('vgg_frozen.h5')

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255,
                                                                zoom_range=0.05,
                                                                rotation_range=25,
                                                                width_shift_range=0.05,
                                                                height_shift_range=0.05,
                                                                shear_range=0.05, horizontal_flip=True,
                                                                fill_mode='nearest')

val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# build image augmentation generators
train_generator = train_datagen.flow(train_data, train_labels_enc, batch_size=BATCH_SIZE, shuffle=True)
val_generator = val_datagen.flow(val_data, val_labels_enc, batch_size=BATCH_SIZE, shuffle=False)

# %%
img_id = 0
sample_generator = train_datagen.flow(train_data[img_id:img_id+1], train_labels[img_id:img_id+1],
                                      batch_size=1)
sample = [next(sample_generator) for i in range(0,5)]
fig, ax = plt.subplots(1,5, figsize=(16, 6))
print('Labels:', [item[1][0] for item in sample])
l = [ax[i].imshow(sample[i][0][0]) for i in range(0,5)]
# Out:
# Labels: ['malaria', 'malaria', 'malaria', 'malaria', 'malaria']

# %%
vgg = tf.keras.applications.vgg19.VGG19(include_top=False, weights='imagenet',
                                        input_shape=INPUT_SHAPE)
# Freeze the layers
vgg.trainable = True

set_trainable = False
for layer in vgg.layers:
    if layer.name in ['block5_conv1', 'block4_conv1']:
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
   
base_vgg = vgg
base_out = base_vgg.output
pool_out = tf.keras.layers.Flatten()(base_out)
hidden1 = tf.keras.layers.Dense(512, activation='relu')(pool_out)
drop1 = tf.keras.layers.Dropout(rate=0.3)(hidden1)
hidden2 = tf.keras.layers.Dense(512, activation='relu')(drop1)
drop2 = tf.keras.layers.Dropout(rate=0.3)(hidden2)

out = tf.keras.layers.Dense(1, activation='sigmoid')(drop2)

model = tf.keras.Model(inputs=base_vgg.input, outputs=out)
model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=1e-5),
                loss='binary_crossentropy',
                metrics=['accuracy'])

print("Total Layers:", len(model.layers))
print("Total trainable layers:", sum([1 for l in model.layers if l.trainable]))
# Out:
# Total Layers: 28
# Total trainable layers: 16

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                              patience=2, min_lr=0.000001)

callbacks = [reduce_lr, tensorboard_callback]
train_steps_per_epoch = train_generator.n // train_generator.batch_size
val_steps_per_epoch = val_generator.n // val_generator.batch_size
history = model.fit_generator(train_generator, steps_per_epoch=train_steps_per_epoch, epochs=EPOCHS,
                              validation_data=val_generator, validation_steps=val_steps_per_epoch,
                              verbose=1)
# Out:
# WARNING:tensorflow:From <ipython-input-22-cda37ea895b4>:10: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/25
# 271/271 [==============================] - 116s 430ms/step - loss: 0.2237 - accuracy: 0.9111 - val_loss: 0.1261 - val_accuracy: 0.9573
# Epoch 2/25
# 271/271 [==============================] - 115s 424ms/step - loss: 0.1432 - accuracy: 0.9540 - val_loss: 0.1172 - val_accuracy: 0.9604
# Epoch 3/25
# 271/271 [==============================] - 115s 424ms/step - loss: 0.1283 - accuracy: 0.9579 - val_loss: 0.1296 - val_accuracy: 0.9609
# Epoch 4/25
# 271/271 [==============================] - 115s 423ms/step - loss: 0.1216 - accuracy: 0.9581 - val_loss: 0.1209 - val_accuracy: 0.9635
# Epoch 5/25
# 271/271 [==============================] - 115s 423ms/step - loss: 0.1149 - accuracy: 0.9616 - val_loss: 0.1063 - val_accuracy: 0.9615
# Epoch 6/25
# 271/271 [==============================] - 115s 423ms/step - loss: 0.1075 - accuracy: 0.9632 - val_loss: 0.1024 - val_accuracy: 0.9656
# Epoch 7/25
# 271/271 [==============================] - 114s 422ms/step - loss: 0.1037 - accuracy: 0.9646 - val_loss: 0.1153 - val_accuracy: 0.9641
# Epoch 8/25
# 271/271 [==============================] - 114s 422ms/step - loss: 0.1015 - accuracy: 0.9659 - val_loss: 0.1074 - val_accuracy: 0.9651
# Epoch 9/25
# 271/271 [==============================] - 114s 422ms/step - loss: 0.0969 - accuracy: 0.9667 - val_loss: 0.1036 - val_accuracy: 0.9656
# Epoch 10/25
# 271/271 [==============================] - 115s 423ms/step - loss: 0.0931 - accuracy: 0.9682 - val_loss: 0.1007 - val_accuracy: 0.9667
# Epoch 11/25
# 271/271 [==============================] - 114s 422ms/step - loss: 0.0920 - accuracy: 0.9682 - val_loss: 0.1119 - val_accuracy: 0.9589
# Epoch 12/25
# 271/271 [==============================] - 114s 422ms/step - loss: 0.0919 - accuracy: 0.9681 - val_loss: 0.0998 - val_accuracy: 0.9688
# Epoch 13/25
# 271/271 [==============================] - 114s 422ms/step - loss: 0.0912 - accuracy: 0.9685 - val_loss: 0.1439 - val_accuracy: 0.9630
# Epoch 14/25
# 271/271 [==============================] - 114s 422ms/step - loss: 0.0885 - accuracy: 0.9698 - val_loss: 0.0990 - val_accuracy: 0.9672
# Epoch 15/25
# 271/271 [==============================] - 114s 422ms/step - loss: 0.0869 - accuracy: 0.9695 - val_loss: 0.1215 - val_accuracy: 0.9615
# Epoch 16/25
# 271/271 [==============================] - 114s 422ms/step - loss: 0.0843 - accuracy: 0.9717 - val_loss: 0.1087 - val_accuracy: 0.9641
# Epoch 17/25
# 271/271 [==============================] - 114s 421ms/step - loss: 0.0850 - accuracy: 0.9709 - val_loss: 0.1233 - val_accuracy: 0.9661
# Epoch 18/25
# 271/271 [==============================] - 114s 421ms/step - loss: 0.0857 - accuracy: 0.9710 - val_loss: 0.1169 - val_accuracy: 0.9682
# Epoch 19/25
# 271/271 [==============================] - 114s 421ms/step - loss: 0.0853 - accuracy: 0.9706 - val_loss: 0.1366 - val_accuracy: 0.9615
# Epoch 20/25
# 271/271 [==============================] - 114s 421ms/step - loss: 0.0836 - accuracy: 0.9712 - val_loss: 0.1077 - val_accuracy: 0.9651
# Epoch 21/25
# 271/271 [==============================] - 114s 421ms/step - loss: 0.0838 - accuracy: 0.9728 - val_loss: 0.0975 - val_accuracy: 0.9682
# Epoch 22/25
# 271/271 [==============================] - 114s 421ms/step - loss: 0.0800 - accuracy: 0.9731 - val_loss: 0.1108 - val_accuracy: 0.9682
# Epoch 23/25
# 271/271 [==============================] - 114s 422ms/step - loss: 0.0823 - accuracy: 0.9728 - val_loss: 0.1337 - val_accuracy: 0.9672
# Epoch 24/25
# 271/271 [==============================] - 114s 421ms/step - loss: 0.0822 - accuracy: 0.9733 - val_loss: 0.1034 - val_accuracy: 0.9698
# Epoch 25/25
# 271/271 [==============================] - 114s 421ms/step - loss: 0.0824 - accuracy: 0.9718 - val_loss: 0.1075 - val_accuracy: 0.9682

# %%
model.save('vgg_finetuned.h5')

# %%
test_imgs_scaled = test_data / 255.
test_imgs_scaled.shape, test_labels.shape
# Out:
# ((8268, 125, 125, 3), (8268,))

# %%
# Load Saved Deep Learning Models
basic_cnn = tf.keras.models.load_model('./basic_cnn.h5')
vgg_frz = tf.keras.models.load_model('./vgg_frozen.h5')
vgg_ft = tf.keras.models.load_model('./vgg_finetuned.h5')

# Make Predictions on Test Data
basic_cnn_preds = basic_cnn.predict(test_imgs_scaled, batch_size=512)
vgg_frz_preds = vgg_frz.predict(test_imgs_scaled, batch_size=512)
vgg_ft_preds = vgg_ft.predict(test_imgs_scaled, batch_size=512)

basic_cnn_pred_labels = le.inverse_transform([1 if pred > 0.5 else 0
                                                  for pred in basic_cnn_preds.ravel()])
vgg_frz_pred_labels = le.inverse_transform([1 if pred > 0.5 else 0
                                                  for pred in vgg_frz_preds.ravel()])
vgg_ft_pred_labels = le.inverse_transform([1 if pred > 0.5 else 0
                                                  for pred in vgg_ft_preds.ravel()])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-25-99700f4dc07c> in <module>()
#       1 # Load Saved Deep Learning Models
# ----> 2 basic_cnn = tf.keras.models.load_model('./basic_cnn.h5')
#       3 vgg_frz = tf.keras.models.load_model('./vgg_frozen.h5')
#       4 vgg_ft = tf.keras.models.load_model('./vgg_finetuned.h5')
#       5
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     184     filepath = path_to_string(filepath)
#     185     if isinstance(filepath, six.string_types):
# --> 186       loader_impl.parse_saved_model(filepath)
#     187       return saved_model_load.load(filepath, compile, options)
#     188
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     111                   (export_dir,
#     112                    constants.SAVED_MODEL_FILENAME_PBTXT,
# --> 113                    constants.SAVED_MODEL_FILENAME_PB))
#     114
#     115
#
# OSError: SavedModel file does not exist at: ./basic_cnn.h5/{saved_model.pbtxt|saved_model.pb}

# %%
import model_evaluation_utils as meu
import pandas as pd

basic_cnn_metrics = meu.get_metrics(true_labels=test_labels, predicted_labels=basic_cnn_pred_labels)
vgg_frz_metrics = meu.get_metrics(true_labels=test_labels, predicted_labels=vgg_frz_pred_labels)
vgg_ft_metrics = meu.get_metrics(true_labels=test_labels, predicted_labels=vgg_ft_pred_labels)

pd.DataFrame([basic_cnn_metrics, vgg_frz_metrics, vgg_ft_metrics],
             index=['Basic CNN', 'VGG-19 Frozen', 'VGG-19 Fine-tuned'])
